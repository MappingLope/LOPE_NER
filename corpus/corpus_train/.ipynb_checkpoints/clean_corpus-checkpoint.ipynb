# %%
def validate_conll_file(path):
    print(f"\n📂 Validating file: {path}\n" + "-"*60)
    
    with open(path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    sentence = []
    for i, line in enumerate(lines):
        stripped = line.strip()

        # -------- Malformed line (should have at least 2 columns) --------
        if stripped and len(stripped.split()) < 2:
            print(f"{path}:{i + 1}: ❌ Malformed line: '{stripped}'")

        # -------- Empty sentence block (multiple blank lines) --------
        if stripped == "":
            if sentence == []:
                # Look back a few lines for context
                context_start = max(0, i - 3)
                context = "".join(lines[context_start:i]).strip()
                print(f"{path}:{i + 1}: ⚠️ Empty sentence block detected. Context:\n---\n{context}\n---\n")
            sentence = []
        else:
            sentence.append(stripped)


# -------------- Run this block to validate your dataset ----------------
if __name__ == "__main__":
    files_to_check = ["train.txt", "dev.txt", "test.txt"]  # or your actual filenames

    for file_path in files_to_check:
        validate_conll_file(file_path)
# Out:
# 📂 Validating file: train.txt
# ------------------------------------------------------------
# train.txt:375: ❌ Malformed line: 'O'
# train.txt:538: ❌ Malformed line: 'O'
# train.txt:660: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:768: ⚠️ Empty sentence block detected. Context:
# ---
# Éntrense B-PER
# . O
# ---
#
# train.txt:1380: ⚠️ Empty sentence block detected. Context:
# ---
# bastantes O
# . O
# ---
#
# train.txt:1548: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse O
# . O
# ---
#
# train.txt:2310: ❌ Malformed line: 'O'
# train.txt:2348: ❌ Malformed line: '!'
# train.txt:2419: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:2557: ❌ Malformed line: 'O'
# train.txt:2592: ⚠️ Empty sentence block detected. Context:
# ---
# Dichas O
# . O
# ---
#
# train.txt:2837: ❌ Malformed line: '!'
# train.txt:3164: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:3276: ❌ Malformed line: 'O'
# train.txt:4030: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:4037: ⚠️ Empty sentence block detected. Context:
# ---
# , O
# . O
# ---
#
# train.txt:5203: ❌ Malformed line: 'O'
# train.txt:5883: ❌ Malformed line: 'O'
# train.txt:5890: ❌ Malformed line: 'O'
# train.txt:6168: ❌ Malformed line: 'O'
# train.txt:6174: ❌ Malformed line: 'O'
# train.txt:6305: ❌ Malformed line: 'O'
# train.txt:6489: ❌ Malformed line: 'O'
# train.txt:6497: ❌ Malformed line: 'O'
# train.txt:6778: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:7044: ❌ Malformed line: 'O'
# train.txt:7780: ⚠️ Empty sentence block detected. Context:
# ---
# Dichos O
# . O
# ---
#
# train.txt:8273: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:8474: ❌ Malformed line: 'O'
# train.txt:8604: ❌ Malformed line: 'O'
# train.txt:8928: ⚠️ Empty sentence block detected. Context:
# ---
# Dichos O
# . O
# ---
#
# train.txt:9027: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:9146: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:9219: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:9296: ❌ Malformed line: 'O'
# train.txt:9339: ❌ Malformed line: 'O'
# train.txt:9653: ⚠️ Empty sentence block detected. Context:
# ---
# entre O
# . O
# ---
#
# train.txt:10234: ⚠️ Empty sentence block detected. Context:
# ---
# ansí O
# . O
# ---
#
# train.txt:10622: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:10890: ⚠️ Empty sentence block detected. Context:
# ---
# Váyanse O
# . O
# ---
#
# train.txt:11548: ❌ Malformed line: 'O'
# train.txt:11722: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# train.txt:12011: ⚠️ Empty sentence block detected. Context:
# ---
# Váyase O
# . O
# ---
#
# train.txt:12211: ❌ Malformed line: 'O'
# train.txt:12563: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:13049: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:13972: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# train.txt:14189: ⚠️ Empty sentence block detected. Context:
# ---
# Dichos O
# . O
# ---
#
# train.txt:14366: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:15464: ❌ Malformed line: 'O'
# train.txt:15483: ❌ Malformed line: 'O'
# train.txt:15571: ⚠️ Empty sentence block detected. Context:
# ---
# Dichos O
# . O
# ---
#
# train.txt:15642: ❌ Malformed line: 'O'
# train.txt:15650: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:16664: ❌ Malformed line: 'O'
# train.txt:16846: ⚠️ Empty sentence block detected. Context:
# ---
# No. O
# ---
#
# train.txt:16854: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:17689: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:18342: ⚠️ Empty sentence block detected. Context:
# ---
# Váyanse O
# . O
# ---
#
# train.txt:18788: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:19768: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:19941: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:20001: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:20333: ⚠️ Empty sentence block detected. Context:
# ---
# Váyase O
# . O
# ---
#
# train.txt:20347: ❌ Malformed line: 'O'
# train.txt:20611: ⚠️ Empty sentence block detected. Context:
# ---
# Váyase O
# . O
# ---
#
# train.txt:20668: ❌ Malformed line: '!'
# train.txt:20706: ⚠️ Empty sentence block detected. Context:
# ---
# Váyanse O
# . O
# ---
#
# train.txt:20753: ❌ Malformed line: 'O'
# train.txt:21092: ❌ Malformed line: 'O'
# train.txt:21201: ❌ Malformed line: 'O'
# train.txt:21352: ⚠️ Empty sentence block detected. Context:
# ---
# y O
# . O
# ---
#
# train.txt:21728: ❌ Malformed line: 'O'
# train.txt:21812: ❌ Malformed line: 'O'
# train.txt:21884: ❌ Malformed line: 'O'
# train.txt:21997: ⚠️ Empty sentence block detected. Context:
# ---
# Váyase O
# . O
# ---
#
# train.txt:22252: ❌ Malformed line: 'O'
# train.txt:22562: ⚠️ Empty sentence block detected. Context:
# ---
# soldado O
# . O
# ---
#
# train.txt:22634: ⚠️ Empty sentence block detected. Context:
# ---
# soldado O
# . O
# ---
#
# train.txt:22705: ⚠️ Empty sentence block detected. Context:
# ---
# soldado O
# . O
# ---
#
# train.txt:22773: ⚠️ Empty sentence block detected. Context:
# ---
# soldado O
# . O
# ---
#
# train.txt:23311: ❌ Malformed line: 'O'
# train.txt:24982: ❌ Malformed line: 'O'
# train.txt:25064: ❌ Malformed line: 'O'
# train.txt:25138: ❌ Malformed line: 'O'
# train.txt:27769: ❌ Malformed line: 'O'
# train.txt:27933: ⚠️ Empty sentence block detected. Context:
# ---
# Dentro O
# . O
# ---
#
# train.txt:27948: ⚠️ Empty sentence block detected. Context:
# ---
# engañados O
# . O
# ---
#
# train.txt:28828: ❌ Malformed line: 'O'
# train.txt:29627: ⚠️ Empty sentence block detected. Context:
# ---
# Sale O
# . O
# ---
#
# train.txt:31381: ❌ Malformed line: 'O'
# train.txt:33228: ⚠️ Empty sentence block detected. Context:
# ---
# los O
# . O
# ---
#
# train.txt:33976: ❌ Malformed line: 'O'
# train.txt:34275: ❌ Malformed line: 'O'
# train.txt:34604: ❌ Malformed line: 'O'
# train.txt:35372: ❌ Malformed line: 'O'
# train.txt:39353: ❌ Malformed line: 'O'
# train.txt:39906: ⚠️ Empty sentence block detected. Context:
# ---
# música O
# . O
# ---
#
# train.txt:42805: ❌ Malformed line: '!'
# train.txt:44439: ❌ Malformed line: '.'
# train.txt:45064: ❌ Malformed line: '.'
# train.txt:45549: ❌ Malformed line: 'O'
# train.txt:46212: ❌ Malformed line: '.'
# train.txt:46705: ⚠️ Empty sentence block detected. Context:
# ---
# alcaldes O
# . O
# ---
#
# train.txt:46709: ⚠️ Empty sentence block detected. Context:
# ---
# Cantan O
# . O
# ---
#
# train.txt:46710: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:47127: ⚠️ Empty sentence block detected. Context:
# ---
# Cantan O
# . O
# ---
#
# train.txt:47128: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:47258: ❌ Malformed line: 'O'
# train.txt:47261: ❌ Malformed line: 'O'
# train.txt:47264: ❌ Malformed line: 'O'
# train.txt:47321: ❌ Malformed line: '.'
# train.txt:47356: ❌ Malformed line: 'O'
# train.txt:47590: ⚠️ Empty sentence block detected. Context:
# ---
# Real I-LOC
# . O
# ---
#
# train.txt:47986: ❌ Malformed line: '.'
# train.txt:48285: ❌ Malformed line: 'O'
# train.txt:48344: ❌ Malformed line: '.'
# train.txt:49140: ❌ Malformed line: 'O'
# train.txt:49530: ❌ Malformed line: 'O'
# train.txt:50558: ❌ Malformed line: 'O'
# train.txt:50635: ❌ Malformed line: 'O'
# train.txt:51441: ❌ Malformed line: 'O'
# train.txt:51607: ❌ Malformed line: 'O'
# train.txt:51724: ❌ Malformed line: 'O'
# train.txt:52780: ❌ Malformed line: 'O'
# train.txt:52837: ❌ Malformed line: 'O'
# train.txt:52923: ❌ Malformed line: 'O'
# train.txt:53323: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# train.txt:53404: ❌ Malformed line: 'O'
# train.txt:53435: ❌ Malformed line: 'O'
# train.txt:53504: ❌ Malformed line: 'O'
# train.txt:53584: ❌ Malformed line: 'O'
# train.txt:53913: ⚠️ Empty sentence block detected. Context:
# ---
# paredes O
# pasan. O
# ---
#
# train.txt:54182: ❌ Malformed line: '!'
# train.txt:54266: ❌ Malformed line: 'O'
# train.txt:54555: ❌ Malformed line: 'O'
# train.txt:55394: ❌ Malformed line: 'O'
# train.txt:56141: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:56545: ⚠️ Empty sentence block detected. Context:
# ---
# Vase O
# . O
# ---
#
# train.txt:56605: ❌ Malformed line: 'O'
# train.txt:56695: ❌ Malformed line: 'O'
# train.txt:58609: ❌ Malformed line: 'O'
# train.txt:74950: ⚠️ Empty sentence block detected. Context:
# ---
# brío O
# . O
# ---
#
# train.txt:74951: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:106736: ❌ Malformed line: 'O'
# train.txt:107509: ❌ Malformed line: 'O'
# train.txt:109325: ❌ Malformed line: 'O'
# train.txt:109331: ❌ Malformed line: 'O'
# train.txt:109480: ❌ Malformed line: 'O'
# train.txt:109996: ❌ Malformed line: 'O'
# train.txt:110329: ❌ Malformed line: 'O'
# train.txt:110388: ❌ Malformed line: 'O'
# train.txt:110451: ❌ Malformed line: 'O'
# train.txt:110611: ❌ Malformed line: 'O'
# train.txt:111023: ❌ Malformed line: 'O'
# train.txt:111128: ❌ Malformed line: 'O'
# train.txt:112864: ❌ Malformed line: 'O'
# train.txt:114482: ❌ Malformed line: 'O'
# train.txt:114784: ❌ Malformed line: 'O'
# train.txt:116208: ⚠️ Empty sentence block detected. Context:
# ---
# mío O
# . O
# ---
#
# train.txt:118477: ❌ Malformed line: 'O'
# train.txt:124094: ❌ Malformed line: 'O'
# train.txt:124466: ❌ Malformed line: 'O'
# train.txt:124575: ⚠️ Empty sentence block detected. Context:
# ---
# carta O
# . O
# ---
#
# train.txt:127365: ❌ Malformed line: 'O'
# train.txt:128034: ❌ Malformed line: 'O'
# train.txt:128896: ❌ Malformed line: 'O'
# train.txt:129054: ⚠️ Empty sentence block detected. Context:
# ---
# voces O
# . O
# ---
#
# train.txt:129671: ⚠️ Empty sentence block detected. Context:
# ---
# léele O
# . O
# ---
#
# train.txt:129887: ⚠️ Empty sentence block detected. Context:
# ---
# Lea O
# . O
# ---
#
# train.txt:129888: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:133419: ❌ Malformed line: 'O'
# train.txt:133840: ❌ Malformed line: 'O'
# train.txt:135493: ⚠️ Empty sentence block detected. Context:
# ---
# papel O
# . O
# ---
#
# train.txt:136478: ❌ Malformed line: 'O'
# train.txt:137354: ❌ Malformed line: 'O'
# train.txt:144067: ❌ Malformed line: 'O'
# train.txt:144985: ❌ Malformed line: 'O'
# train.txt:149028: ⚠️ Empty sentence block detected. Context:
# ---
# dentro O
# . O
# ---
#
# train.txt:149069: ⚠️ Empty sentence block detected. Context:
# ---
# Canten O
# . O
# ---
#
# train.txt:149489: ❌ Malformed line: 'O'
# train.txt:149509: ❌ Malformed line: 'O'
# train.txt:151017: ❌ Malformed line: 'O'
# train.txt:151786: ❌ Malformed line: 'O'
# train.txt:152575: ❌ Malformed line: '.'
# train.txt:152713: ❌ Malformed line: '.'
# train.txt:152715: ❌ Malformed line: 'O'
# train.txt:152753: ❌ Malformed line: 'O'
# train.txt:152766: ❌ Malformed line: 'O'
# train.txt:153105: ❌ Malformed line: '.'
# train.txt:153422: ❌ Malformed line: '.'
# train.txt:153904: ❌ Malformed line: 'O'
# train.txt:154567: ⚠️ Empty sentence block detected. Context:
# ---
# váyanse O
# . O
# ---
#
# train.txt:154688: ❌ Malformed line: '.'
# train.txt:155691: ❌ Malformed line: '.'
# train.txt:155947: ⚠️ Empty sentence block detected. Context:
# ---
# Lea O
# . O
# ---
#
# train.txt:156835: ❌ Malformed line: '.'
# train.txt:156857: ❌ Malformed line: '.'
# train.txt:157286: ❌ Malformed line: '.'
# train.txt:157359: ❌ Malformed line: '.'
# train.txt:157389: ❌ Malformed line: '.'
# train.txt:158023: ❌ Malformed line: '?'
# train.txt:158026: ❌ Malformed line: 'O'
# train.txt:158036: ❌ Malformed line: 'O'
# train.txt:158261: ❌ Malformed line: '.'
# train.txt:158748: ❌ Malformed line: '.'
# train.txt:158972: ❌ Malformed line: '.'
# train.txt:158974: ❌ Malformed line: 'O'
# train.txt:159055: ❌ Malformed line: '.'
# train.txt:159359: ❌ Malformed line: 'O'
# train.txt:159375: ❌ Malformed line: 'O'
# train.txt:160321: ❌ Malformed line: '.'
# train.txt:160713: ❌ Malformed line: 'O'
# train.txt:160785: ❌ Malformed line: '.'
# train.txt:161137: ❌ Malformed line: '!'
# train.txt:161214: ⚠️ Empty sentence block detected. Context:
# ---
# Lea O
# . O
# ---
#
# train.txt:161700: ❌ Malformed line: '.'
# train.txt:162119: ❌ Malformed line: 'O'
# train.txt:162315: ❌ Malformed line: '.'
# train.txt:162704: ❌ Malformed line: '.'
# train.txt:162785: ❌ Malformed line: '.'
# train.txt:162829: ❌ Malformed line: 'O'
# train.txt:163141: ⚠️ Empty sentence block detected. Context:
# ---
# dentro O
# . O
# ---
#
# train.txt:163142: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:163444: ❌ Malformed line: '.'
# train.txt:163669: ❌ Malformed line: '.'
# train.txt:163814: ❌ Malformed line: '.'
# train.txt:164150: ❌ Malformed line: '.'
# train.txt:164791: ❌ Malformed line: '.'
# train.txt:165034: ❌ Malformed line: 'O'
# train.txt:165503: ❌ Malformed line: 'O'
# train.txt:165526: ❌ Malformed line: '.'
# train.txt:165543: ❌ Malformed line: 'O'
# train.txt:165562: ❌ Malformed line: '.'
# train.txt:165795: ⚠️ Empty sentence block detected. Context:
# ---
# alta O
# . O
# ---
#
# train.txt:165804: ⚠️ Empty sentence block detected. Context:
# ---
# escribiendo O
# . O
# ---
#
# train.txt:165805: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# train.txt:165958: ❌ Malformed line: '.'
# train.txt:166174: ❌ Malformed line: '.'
# train.txt:166249: ❌ Malformed line: '.'
# train.txt:166321: ❌ Malformed line: '.'
# train.txt:166538: ❌ Malformed line: '.'
# train.txt:166738: ❌ Malformed line: '.'
# train.txt:167294: ❌ Malformed line: '.'
# train.txt:167392: ❌ Malformed line: '.'
# train.txt:167456: ❌ Malformed line: '.'
# train.txt:167571: ❌ Malformed line: '.'
# train.txt:167910: ❌ Malformed line: '!'
# train.txt:167926: ❌ Malformed line: '.'
# train.txt:168141: ❌ Malformed line: '.'
# train.txt:169361: ❌ Malformed line: '.'
# train.txt:169400: ❌ Malformed line: '.'
# train.txt:169871: ❌ Malformed line: '.'
# train.txt:169995: ❌ Malformed line: '.'
# train.txt:170253: ❌ Malformed line: 'O'
# train.txt:170256: ❌ Malformed line: 'O'
# train.txt:170259: ❌ Malformed line: 'O'
# train.txt:170314: ❌ Malformed line: '.'
# train.txt:170356: ❌ Malformed line: '.'
# train.txt:170640: ❌ Malformed line: '.'
# train.txt:170913: ❌ Malformed line: 'O'
# train.txt:171026: ❌ Malformed line: '.'
# train.txt:171155: ❌ Malformed line: '.'
# train.txt:171659: ❌ Malformed line: '?'
# train.txt:171703: ❌ Malformed line: 'O'
# train.txt:171712: ❌ Malformed line: 'O'
# train.txt:171813: ❌ Malformed line: '?'
# train.txt:172065: ❌ Malformed line: '.'
# train.txt:172102: ❌ Malformed line: 'O'
# train.txt:172165: ❌ Malformed line: '.'
# train.txt:172209: ❌ Malformed line: '.'
# train.txt:172257: ❌ Malformed line: 'O'
# train.txt:172563: ❌ Malformed line: '.'
# train.txt:172776: ❌ Malformed line: '.'
# train.txt:172977: ❌ Malformed line: '.'
# train.txt:173044: ❌ Malformed line: '.'
# train.txt:173402: ❌ Malformed line: '.'
# train.txt:173674: ❌ Malformed line: 'O'
# train.txt:173863: ❌ Malformed line: 'O'
# train.txt:174018: ❌ Malformed line: '.'
# train.txt:174460: ❌ Malformed line: '.'
# train.txt:174522: ❌ Malformed line: '.'
# train.txt:174548: ❌ Malformed line: '.'
# train.txt:174764: ❌ Malformed line: '.'
# train.txt:174885: ❌ Malformed line: 'O'
# train.txt:174980: ❌ Malformed line: '.'
# train.txt:175439: ❌ Malformed line: '.'
# train.txt:175461: ⚠️ Empty sentence block detected. Context:
# ---
# puerta O
# . O
# ---
#
#
# 📂 Validating file: dev.txt
# ------------------------------------------------------------
# dev.txt:10762: ❌ Malformed line: '…'
#
# 📂 Validating file: test.txt
# ------------------------------------------------------------
# test.txt:2440: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse O
# . O
# ---
#
# test.txt:2610: ❌ Malformed line: 'O'
# test.txt:3110: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse O
# . O
# ---
#
# test.txt:3289: ⚠️ Empty sentence block detected. Context:
# ---
# luego O
# ! O
# ---
#
# test.txt:4050: ❌ Malformed line: 'O'
# test.txt:5075: ❌ Malformed line: 'O'
# test.txt:5142: ❌ Malformed line: 'O'
# test.txt:5242: ❌ Malformed line: 'O'
# test.txt:5308: ❌ Malformed line: 'O'
# test.txt:6037: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# test.txt:6267: ❌ Malformed line: 'O'
# test.txt:6522: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# test.txt:7279: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# test.txt:9371: ❌ Malformed line: 'O'
# test.txt:9725: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse O
# . O
# ---
#
# test.txt:10270: ❌ Malformed line: 'O'
# test.txt:10486: ⚠️ Empty sentence block detected. Context:
# ---
# el O
# . O
# ---
#
# test.txt:10913: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# test.txt:11758: ❌ Malformed line: 'O'
# test.txt:11852: ❌ Malformed line: 'O'
# test.txt:13576: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# test.txt:18456: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse O
# . O
# ---
#
# test.txt:18469: ⚠️ Empty sentence block detected. Context:
# ---
# villancico O
# . O
# ---
#
# test.txt:18473: ⚠️ Empty sentence block detected. Context:
# ---
# Cantan O
# . O
# ---
#
# test.txt:19219: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# test.txt:19936: ⚠️ Empty sentence block detected. Context:
# ---
# Vamos O
# . O
# ---
#
# test.txt:19937: ⚠️ Empty sentence block detected. Context:
# ---
# . O
# ---
#
# test.txt:19945: ⚠️ Empty sentence block detected. Context:
# ---
# Vanse B-PER
# . O
# ---
#
# test.txt:20947: ❌ Malformed line: 'O'
# test.txt:21008: ❌ Malformed line: 'O'
# test.txt:21764: ❌ Malformed line: 'O'
# test.txt:21968: ❌ Malformed line: 'O'
# test.txt:22007: ❌ Malformed line: 'O'
# test.txt:22013: ❌ Malformed line: 'O'
# test.txt:22134: ❌ Malformed line: 'O'
