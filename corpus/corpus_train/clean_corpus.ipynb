# %%
import re

def clean_line(line):
    # Eliminar todo tipo de comillas simples y dobles
    line = line.replace("'", "").replace('"', "")
    
    # Eliminar paréntesis y corchetes
    line = line.replace("(", "").replace(")", "").replace("[", "").replace("]", "")
    
    # Eliminar dos o más puntos consecutivos (.., ..., etc)
    line = re.sub(r'\.{2,}', '', line)
    
    return line

def validate_conll_file(path):
    print(f"\n📂 Validating file: {path}\n" + "-"*60)
    
    with open(path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    sentence = []
    for i, line in enumerate(lines):
        # Limpiar la línea primero
        cleaned_line = clean_line(line)
        stripped = cleaned_line.strip()

        # -------- Malformed line (should have at least 2 columns) --------
        if stripped and len(stripped.split()) < 2:
            print(f"{path}:{i + 1}: ❌ Malformed line after cleaning: '{stripped}'")

        # -------- Empty sentence block (multiple blank lines) --------
        if stripped == "":
            if sentence == []:
                # Look back a few lines for context
                context_start = max(0, i - 3)
                context = "".join(lines[context_start:i]).strip()
                print(f"{path}:{i + 1}: ⚠️ Empty sentence block detected. Context:\n---\n{context}\n---\n")
            sentence = []
        else:
            sentence.append(stripped)


# -------------- Run this block to validate your dataset ----------------
if __name__ == "__main__":
    files_to_check = ["train.txt", "dev.txt", "test.txt"]  # or your actual filenames

    for file_path in files_to_check:
        validate_conll_file(file_path)
# Out:
# 📂 Validating file: train.txt
# ------------------------------------------------------------
# train.txt:141: ❌ Malformed line after cleaning: 'O'
# train.txt:180: ❌ Malformed line after cleaning: 'O'
# train.txt:186: ❌ Malformed line after cleaning: 'O'
# train.txt:306: ❌ Malformed line after cleaning: 'O'
# train.txt:478: ❌ Malformed line after cleaning: 'O'
# train.txt:480: ❌ Malformed line after cleaning: 'O'
# train.txt:486: ❌ Malformed line after cleaning: 'O'
# train.txt:490: ❌ Malformed line after cleaning: 'O'
# train.txt:753: ❌ Malformed line after cleaning: 'O'
# train.txt:755: ❌ Malformed line after cleaning: 'O'
# train.txt:759: ❌ Malformed line after cleaning: 'O'
# train.txt:821: ❌ Malformed line after cleaning: 'O'
# train.txt:825: ❌ Malformed line after cleaning: 'O'
# train.txt:839: ❌ Malformed line after cleaning: 'O'
# train.txt:843: ❌ Malformed line after cleaning: 'O'
# train.txt:847: ❌ Malformed line after cleaning: 'O'
# train.txt:851: ❌ Malformed line after cleaning: 'O'
# train.txt:923: ❌ Malformed line after cleaning: 'O'
# train.txt:1042: ❌ Malformed line after cleaning: 'O'
# train.txt:1046: ❌ Malformed line after cleaning: 'O'
# train.txt:1047: ❌ Malformed line after cleaning: 'O'
# train.txt:1049: ❌ Malformed line after cleaning: 'O'
# train.txt:1050: ❌ Malformed line after cleaning: 'O'
# train.txt:1054: ❌ Malformed line after cleaning: 'O'
# train.txt:1154: ❌ Malformed line after cleaning: 'O'
# train.txt:1158: ❌ Malformed line after cleaning: 'O'
# train.txt:1159: ❌ Malformed line after cleaning: 'O'
# train.txt:1161: ❌ Malformed line after cleaning: 'O'
# train.txt:1162: ❌ Malformed line after cleaning: 'O'
# train.txt:1171: ❌ Malformed line after cleaning: 'O'
# train.txt:1417: ❌ Malformed line after cleaning: 'O'
# train.txt:1429: ❌ Malformed line after cleaning: 'O'
# train.txt:1764: ❌ Malformed line after cleaning: 'O'
# train.txt:1765: ❌ Malformed line after cleaning: 'O'
# train.txt:1929: ❌ Malformed line after cleaning: 'O'
# train.txt:1933: ❌ Malformed line after cleaning: 'O'
# train.txt:1934: ❌ Malformed line after cleaning: 'O'
# train.txt:1937: ❌ Malformed line after cleaning: 'O'
# train.txt:2166: ❌ Malformed line after cleaning: 'O'
# train.txt:2168: ❌ Malformed line after cleaning: 'O'
# train.txt:2181: ❌ Malformed line after cleaning: 'O'
# train.txt:2185: ❌ Malformed line after cleaning: 'O'
# train.txt:2198: ❌ Malformed line after cleaning: 'O'
# train.txt:2203: ❌ Malformed line after cleaning: 'O'
# train.txt:2262: ❌ Malformed line after cleaning: 'O'
# train.txt:2344: ❌ Malformed line after cleaning: 'O'
# train.txt:2346: ❌ Malformed line after cleaning: 'O'
# train.txt:2462: ❌ Malformed line after cleaning: 'O'
# train.txt:2473: ❌ Malformed line after cleaning: 'O'
# train.txt:2594: ❌ Malformed line after cleaning: 'O'
# train.txt:2600: ❌ Malformed line after cleaning: 'O'
# train.txt:2703: ❌ Malformed line after cleaning: 'O'
# train.txt:2808: ❌ Malformed line after cleaning: 'O'
# train.txt:2812: ❌ Malformed line after cleaning: 'O'
# train.txt:2813: ❌ Malformed line after cleaning: 'O'
# train.txt:2815: ❌ Malformed line after cleaning: 'O'
# train.txt:2816: ❌ Malformed line after cleaning: 'O'
# train.txt:2821: ❌ Malformed line after cleaning: 'O'
# train.txt:2884: ❌ Malformed line after cleaning: 'O'
# train.txt:2954: ❌ Malformed line after cleaning: 'O'
# train.txt:2979: ❌ Malformed line after cleaning: 'O'
# train.txt:2981: ❌ Malformed line after cleaning: 'O'
# train.txt:2986: ❌ Malformed line after cleaning: 'O'
# train.txt:2990: ❌ Malformed line after cleaning: 'O'
# train.txt:2991: ❌ Malformed line after cleaning: 'O'
# train.txt:2995: ❌ Malformed line after cleaning: 'O'
# train.txt:3404: ❌ Malformed line after cleaning: 'O'
# train.txt:3406: ❌ Malformed line after cleaning: 'O'
# train.txt:3553: ❌ Malformed line after cleaning: 'O'
# train.txt:3558: ❌ Malformed line after cleaning: 'O'
# train.txt:3559: ❌ Malformed line after cleaning: 'O'
# train.txt:3561: ❌ Malformed line after cleaning: 'O'
# train.txt:3562: ❌ Malformed line after cleaning: 'O'
# train.txt:3566: ❌ Malformed line after cleaning: 'O'
# train.txt:3613: ❌ Malformed line after cleaning: 'O'
# train.txt:3616: ❌ Malformed line after cleaning: 'O'
# train.txt:3623: ❌ Malformed line after cleaning: 'O'
# train.txt:3627: ❌ Malformed line after cleaning: 'O'
# train.txt:3674: ❌ Malformed line after cleaning: 'O'
# train.txt:4179: ❌ Malformed line after cleaning: 'O'
# train.txt:4183: ❌ Malformed line after cleaning: 'O'
# train.txt:4218: ❌ Malformed line after cleaning: 'O'
# train.txt:4354: ❌ Malformed line after cleaning: 'O'
# train.txt:4361: ❌ Malformed line after cleaning: 'O'
# train.txt:4421: ❌ Malformed line after cleaning: 'O'
# train.txt:4426: ❌ Malformed line after cleaning: 'O'
# train.txt:4427: ❌ Malformed line after cleaning: 'O'
# train.txt:4429: ❌ Malformed line after cleaning: 'O'
# train.txt:4430: ❌ Malformed line after cleaning: 'O'
# train.txt:4435: ❌ Malformed line after cleaning: 'O'
# train.txt:4436: ❌ Malformed line after cleaning: 'O'
# train.txt:4440: ❌ Malformed line after cleaning: 'O'
# train.txt:4549: ❌ Malformed line after cleaning: 'O'
# train.txt:4551: ❌ Malformed line after cleaning: 'O'
# train.txt:4682: ❌ Malformed line after cleaning: 'O'
# train.txt:4684: ❌ Malformed line after cleaning: 'O'
# train.txt:4692: ❌ Malformed line after cleaning: 'O'
# train.txt:4695: ❌ Malformed line after cleaning: 'O'
# train.txt:4977: ❌ Malformed line after cleaning: 'O'
# train.txt:4979: ❌ Malformed line after cleaning: 'O'
# train.txt:5002: ❌ Malformed line after cleaning: 'O'
# train.txt:5004: ❌ Malformed line after cleaning: 'O'
# train.txt:5320: ❌ Malformed line after cleaning: 'O'
# train.txt:5322: ❌ Malformed line after cleaning: 'O'
# train.txt:5327: ❌ Malformed line after cleaning: 'O'
# train.txt:5331: ❌ Malformed line after cleaning: 'O'
# train.txt:5601: ❌ Malformed line after cleaning: 'O'
# train.txt:5730: ❌ Malformed line after cleaning: 'O'
# train.txt:5734: ❌ Malformed line after cleaning: 'O'
# train.txt:5971: ❌ Malformed line after cleaning: 'O'
# train.txt:6006: ❌ Malformed line after cleaning: 'O'
# train.txt:6010: ❌ Malformed line after cleaning: 'O'
# train.txt:6035: ❌ Malformed line after cleaning: 'O'
# train.txt:6038: ❌ Malformed line after cleaning: 'O'
# train.txt:6047: ❌ Malformed line after cleaning: 'O'
# train.txt:6049: ❌ Malformed line after cleaning: 'O'
# train.txt:6244: ❌ Malformed line after cleaning: 'O'
# train.txt:6250: ❌ Malformed line after cleaning: 'O'
# train.txt:6287: ❌ Malformed line after cleaning: 'O'
# train.txt:6294: ❌ Malformed line after cleaning: 'O'
# train.txt:6333: ❌ Malformed line after cleaning: 'O'
# train.txt:6335: ❌ Malformed line after cleaning: 'O'
# train.txt:6341: ❌ Malformed line after cleaning: 'O'
# train.txt:6345: ❌ Malformed line after cleaning: 'O'
# train.txt:6453: ❌ Malformed line after cleaning: 'O'
# train.txt:6455: ❌ Malformed line after cleaning: 'O'
# train.txt:6460: ❌ Malformed line after cleaning: 'O'
# train.txt:6464: ❌ Malformed line after cleaning: 'O'
# train.txt:6496: ❌ Malformed line after cleaning: 'O'
# train.txt:6498: ❌ Malformed line after cleaning: 'O'
# train.txt:6504: ❌ Malformed line after cleaning: 'O'
# train.txt:6508: ❌ Malformed line after cleaning: 'O'
# train.txt:6576: ❌ Malformed line after cleaning: 'O'
# train.txt:6582: ❌ Malformed line after cleaning: 'O'
# train.txt:6712: ❌ Malformed line after cleaning: 'O'
# train.txt:6720: ❌ Malformed line after cleaning: 'O'
# train.txt:6818: ❌ Malformed line after cleaning: 'O'
# train.txt:6821: ❌ Malformed line after cleaning: 'O'
# train.txt:6899: ❌ Malformed line after cleaning: 'O'
# train.txt:6907: ❌ Malformed line after cleaning: 'O'
# train.txt:6917: ❌ Malformed line after cleaning: 'O'
# train.txt:6930: ❌ Malformed line after cleaning: 'O'
# train.txt:6959: ❌ Malformed line after cleaning: 'O'
# train.txt:6963: ❌ Malformed line after cleaning: 'O'
# train.txt:6971: ❌ Malformed line after cleaning: 'O'
# train.txt:7021: ❌ Malformed line after cleaning: 'O'
# train.txt:7044: ❌ Malformed line after cleaning: 'O'
# train.txt:7047: ❌ Malformed line after cleaning: 'O'
# train.txt:7062: ❌ Malformed line after cleaning: 'O'
# train.txt:7065: ❌ Malformed line after cleaning: 'O'
# train.txt:7140: ❌ Malformed line after cleaning: 'O'
# train.txt:7143: ❌ Malformed line after cleaning: 'O'
# train.txt:7189: ❌ Malformed line after cleaning: 'O'
# train.txt:7198: ❌ Malformed line after cleaning: 'O'
# train.txt:7199: ❌ Malformed line after cleaning: 'O'
# train.txt:7201: ❌ Malformed line after cleaning: 'O'
# train.txt:7461: ❌ Malformed line after cleaning: 'O'
# train.txt:7656: ❌ Malformed line after cleaning: 'O'
# train.txt:7659: ❌ Malformed line after cleaning: 'O'
# train.txt:7660: ❌ Malformed line after cleaning: 'O'
# train.txt:7673: ❌ Malformed line after cleaning: 'O'
# train.txt:8180: ❌ Malformed line after cleaning: 'O'
# train.txt:8182: ❌ Malformed line after cleaning: 'O'
# train.txt:8186: ❌ Malformed line after cleaning: 'O'
# train.txt:8190: ❌ Malformed line after cleaning: 'O'
# train.txt:8191: ❌ Malformed line after cleaning: 'O'
# train.txt:8196: ❌ Malformed line after cleaning: 'O'
# train.txt:8676: ❌ Malformed line after cleaning: 'O'
# train.txt:8681: ❌ Malformed line after cleaning: 'O'
# train.txt:8682: ❌ Malformed line after cleaning: 'O'
# train.txt:8684: ❌ Malformed line after cleaning: 'O'
# train.txt:8879: ❌ Malformed line after cleaning: 'O'
# train.txt:9008: ❌ Malformed line after cleaning: 'O'
# train.txt:9319: ❌ Malformed line after cleaning: 'O'
# train.txt:9321: ❌ Malformed line after cleaning: 'O'
# train.txt:9329: ❌ Malformed line after cleaning: 'O'
# train.txt:9333: ❌ Malformed line after cleaning: 'O'
# train.txt:9334: ❌ Malformed line after cleaning: 'O'
# train.txt:9337: ❌ Malformed line after cleaning: 'O'
# train.txt:9428: ❌ Malformed line after cleaning: 'O'
# train.txt:9433: ❌ Malformed line after cleaning: 'O'
# train.txt:9434: ❌ Malformed line after cleaning: 'O'
# train.txt:9437: ❌ Malformed line after cleaning: 'O'
# train.txt:9438: ❌ Malformed line after cleaning: 'O'
# train.txt:9442: ❌ Malformed line after cleaning: 'O'
# train.txt:9552: ❌ Malformed line after cleaning: 'O'
# train.txt:9556: ❌ Malformed line after cleaning: 'O'
# train.txt:9557: ❌ Malformed line after cleaning: 'O'
# train.txt:9559: ❌ Malformed line after cleaning: 'O'
# train.txt:9560: ❌ Malformed line after cleaning: 'O'
# train.txt:9564: ❌ Malformed line after cleaning: 'O'
# train.txt:9628: ❌ Malformed line after cleaning: 'O'
# train.txt:9632: ❌ Malformed line after cleaning: 'O'
# train.txt:9633: ❌ Malformed line after cleaning: 'O'
# train.txt:9635: ❌ Malformed line after cleaning: 'O'
# train.txt:9710: ❌ Malformed line after cleaning: 'O'
# train.txt:9717: ❌ Malformed line after cleaning: 'O'
# train.txt:9755: ❌ Malformed line after cleaning: 'O'
# train.txt:9828: ❌ Malformed line after cleaning: 'O'
# train.txt:9832: ❌ Malformed line after cleaning: 'O'
# train.txt:10062: ❌ Malformed line after cleaning: 'O'
# train.txt:10068: ❌ Malformed line after cleaning: 'O'
# train.txt:10069: ❌ Malformed line after cleaning: 'O'
# train.txt:10071: ❌ Malformed line after cleaning: 'O'
# train.txt:10072: ❌ Malformed line after cleaning: 'O'
# train.txt:10075: ❌ Malformed line after cleaning: 'O'
# train.txt:10448: ❌ Malformed line after cleaning: 'O'
# train.txt:10450: ❌ Malformed line after cleaning: 'O'
# train.txt:10455: ❌ Malformed line after cleaning: 'O'
# train.txt:10459: ❌ Malformed line after cleaning: 'O'
# train.txt:10641: ❌ Malformed line after cleaning: 'O'
# train.txt:10646: ❌ Malformed line after cleaning: 'O'
# train.txt:10724: ❌ Malformed line after cleaning: 'O'
# train.txt:10727: ❌ Malformed line after cleaning: 'O'
# train.txt:10802: ❌ Malformed line after cleaning: 'O'
# train.txt:10909: ❌ Malformed line after cleaning: 'O'
# train.txt:10912: ❌ Malformed line after cleaning: 'O'
# train.txt:10917: ❌ Malformed line after cleaning: 'O'
# train.txt:10921: ❌ Malformed line after cleaning: 'O'
# train.txt:10962: ❌ Malformed line after cleaning: 'O'
# train.txt:11039: ❌ Malformed line after cleaning: 'O'
# train.txt:11044: ❌ Malformed line after cleaning: 'O'
# train.txt:11045: ❌ Malformed line after cleaning: 'O'
# train.txt:11047: ❌ Malformed line after cleaning: 'O'
# train.txt:11048: ❌ Malformed line after cleaning: 'O'
# train.txt:11051: ❌ Malformed line after cleaning: 'O'
# train.txt:11308: ❌ Malformed line after cleaning: 'O'
# train.txt:11312: ❌ Malformed line after cleaning: 'O'
# train.txt:11313: ❌ Malformed line after cleaning: 'O'
# train.txt:11315: ❌ Malformed line after cleaning: 'O'
# train.txt:11316: ❌ Malformed line after cleaning: 'O'
# train.txt:11320: ❌ Malformed line after cleaning: 'O'
# train.txt:11925: ❌ Malformed line after cleaning: 'O'
# train.txt:11927: ❌ Malformed line after cleaning: 'O'
# train.txt:11932: ❌ Malformed line after cleaning: 'O'
# train.txt:11936: ❌ Malformed line after cleaning: 'O'
# train.txt:11962: ❌ Malformed line after cleaning: 'O'
# train.txt:12051: ❌ Malformed line after cleaning: 'O'
# train.txt:12053: ❌ Malformed line after cleaning: 'O'
# train.txt:12059: ❌ Malformed line after cleaning: 'O'
# train.txt:12062: ❌ Malformed line after cleaning: 'O'
# train.txt:12134: ❌ Malformed line after cleaning: 'O'
# train.txt:12138: ❌ Malformed line after cleaning: 'O'
# train.txt:12139: ❌ Malformed line after cleaning: 'O'
# train.txt:12141: ❌ Malformed line after cleaning: 'O'
# train.txt:12142: ❌ Malformed line after cleaning: 'O'
# train.txt:12149: ❌ Malformed line after cleaning: 'O'
# train.txt:12424: ❌ Malformed line after cleaning: 'O'
# train.txt:12428: ❌ Malformed line after cleaning: 'O'
# train.txt:12429: ❌ Malformed line after cleaning: 'O'
# train.txt:12431: ❌ Malformed line after cleaning: 'O'
# train.txt:12436: ❌ Malformed line after cleaning: 'O'
# train.txt:12439: ❌ Malformed line after cleaning: 'O'
# train.txt:12461: ❌ Malformed line after cleaning: 'O'
# train.txt:12464: ❌ Malformed line after cleaning: 'O'
# train.txt:12607: ❌ Malformed line after cleaning: 'O'
# train.txt:12610: ❌ Malformed line after cleaning: 'O'
# train.txt:12633: ❌ Malformed line after cleaning: 'O'
# train.txt:12798: ❌ Malformed line after cleaning: 'O'
# train.txt:12878: ❌ Malformed line after cleaning: 'O'
# train.txt:12880: ❌ Malformed line after cleaning: 'O'
# train.txt:12885: ❌ Malformed line after cleaning: 'O'
# train.txt:12889: ❌ Malformed line after cleaning: 'O'
# train.txt:12981: ❌ Malformed line after cleaning: 'O'
# train.txt:12986: ❌ Malformed line after cleaning: 'O'
# train.txt:12987: ❌ Malformed line after cleaning: 'O'
# train.txt:12989: ❌ Malformed line after cleaning: 'O'
# train.txt:12990: ❌ Malformed line after cleaning: 'O'
# train.txt:12994: ❌ Malformed line after cleaning: 'O'
# train.txt:13065: ❌ Malformed line after cleaning: 'O'
# train.txt:13067: ❌ Malformed line after cleaning: 'O'
# train.txt:13072: ❌ Malformed line after cleaning: 'O'
# train.txt:13075: ❌ Malformed line after cleaning: 'O'
# train.txt:13208: ❌ Malformed line after cleaning: 'O'
# train.txt:13211: ❌ Malformed line after cleaning: 'O'
# train.txt:13306: ❌ Malformed line after cleaning: 'O'
# train.txt:13309: ❌ Malformed line after cleaning: 'O'
# train.txt:13417: ❌ Malformed line after cleaning: 'O'
# train.txt:13421: ❌ Malformed line after cleaning: 'O'
# train.txt:13469: ❌ Malformed line after cleaning: 'O'
# train.txt:13471: ❌ Malformed line after cleaning: 'O'
# train.txt:13476: ❌ Malformed line after cleaning: 'O'
# train.txt:13479: ❌ Malformed line after cleaning: 'O'
# train.txt:13480: ❌ Malformed line after cleaning: 'O'
# train.txt:13483: ❌ Malformed line after cleaning: 'O'
# train.txt:13683: ❌ Malformed line after cleaning: 'O'
# train.txt:13685: ❌ Malformed line after cleaning: 'O'
# train.txt:13691: ❌ Malformed line after cleaning: 'O'
# train.txt:13695: ❌ Malformed line after cleaning: 'O'
# train.txt:14027: ❌ Malformed line after cleaning: 'O'
# train.txt:14029: ❌ Malformed line after cleaning: 'O'
# train.txt:14217: ❌ Malformed line after cleaning: 'O'
# train.txt:14381: ❌ Malformed line after cleaning: 'O'
# train.txt:14384: ❌ Malformed line after cleaning: 'O'
# train.txt:14396: ❌ Malformed line after cleaning: 'O'
# train.txt:14400: ❌ Malformed line after cleaning: 'O'
# train.txt:14401: ❌ Malformed line after cleaning: 'O'
# train.txt:14405: ❌ Malformed line after cleaning: 'O'
# train.txt:14432: ❌ Malformed line after cleaning: 'O'
# train.txt:14434: ❌ Malformed line after cleaning: 'O'
# train.txt:14439: ❌ Malformed line after cleaning: 'O'
# train.txt:14442: ❌ Malformed line after cleaning: 'O'
# train.txt:14613: ❌ Malformed line after cleaning: 'O'
# train.txt:14615: ❌ Malformed line after cleaning: 'O'
# train.txt:14620: ❌ Malformed line after cleaning: 'O'
# train.txt:14624: ❌ Malformed line after cleaning: 'O'
# train.txt:14625: ❌ Malformed line after cleaning: 'O'
# train.txt:14628: ❌ Malformed line after cleaning: 'O'
# train.txt:14661: ❌ Malformed line after cleaning: 'O'
# train.txt:14670: ❌ Malformed line after cleaning: 'O'
# train.txt:14734: ❌ Malformed line after cleaning: 'O'
# train.txt:14737: ❌ Malformed line after cleaning: 'O'
# train.txt:14801: ❌ Malformed line after cleaning: 'O'
# train.txt:14805: ❌ Malformed line after cleaning: 'O'
# train.txt:14806: ❌ Malformed line after cleaning: 'O'
# train.txt:14808: ❌ Malformed line after cleaning: 'O'
# train.txt:14809: ❌ Malformed line after cleaning: 'O'
# train.txt:14812: ❌ Malformed line after cleaning: 'O'
# train.txt:14935: ❌ Malformed line after cleaning: 'O'
# train.txt:14938: ❌ Malformed line after cleaning: 'O'
# train.txt:14939: ❌ Malformed line after cleaning: 'O'
# train.txt:14943: ❌ Malformed line after cleaning: 'O'
# train.txt:15167: ❌ Malformed line after cleaning: 'O'
# train.txt:15169: ❌ Malformed line after cleaning: 'O'
# train.txt:15173: ❌ Malformed line after cleaning: 'O'
# train.txt:15176: ❌ Malformed line after cleaning: 'O'
# train.txt:15275: ❌ Malformed line after cleaning: 'O'
# train.txt:15277: ❌ Malformed line after cleaning: 'O'
# train.txt:15609: ❌ Malformed line after cleaning: 'O'
# train.txt:15611: ❌ Malformed line after cleaning: 'O'
# train.txt:15613: ❌ Malformed line after cleaning: 'O'
# train.txt:15621: ❌ Malformed line after cleaning: 'O'
# train.txt:15890: ❌ Malformed line after cleaning: 'O'
# train.txt:15909: ❌ Malformed line after cleaning: 'O'
# train.txt:15924: ❌ Malformed line after cleaning: 'O'
# train.txt:15943: ❌ Malformed line after cleaning: 'O'
# train.txt:15946: ❌ Malformed line after cleaning: 'O'
# train.txt:15951: ❌ Malformed line after cleaning: 'O'
# train.txt:15955: ❌ Malformed line after cleaning: 'O'
# train.txt:15994: ❌ Malformed line after cleaning: 'O'
# train.txt:15996: ❌ Malformed line after cleaning: 'O'
# train.txt:15997: ❌ Malformed line after cleaning: 'O'
# train.txt:16004: ❌ Malformed line after cleaning: 'O'
# train.txt:16005: ❌ Malformed line after cleaning: 'O'
# train.txt:16008: ❌ Malformed line after cleaning: 'O'
# train.txt:16047: ❌ Malformed line after cleaning: 'O'
# train.txt:16053: ❌ Malformed line after cleaning: 'O'
# train.txt:16061: ❌ Malformed line after cleaning: 'O'
# train.txt:16080: ❌ Malformed line after cleaning: 'O'
# train.txt:16088: ❌ Malformed line after cleaning: 'O'
# train.txt:16089: ❌ Malformed line after cleaning: 'O'
# train.txt:16104: ❌ Malformed line after cleaning: 'O'
# train.txt:16114: ❌ Malformed line after cleaning: 'O'
# train.txt:16130: ❌ Malformed line after cleaning: 'O'
# train.txt:16295: ❌ Malformed line after cleaning: 'O'
# train.txt:16297: ❌ Malformed line after cleaning: 'O'
# train.txt:16773: ❌ Malformed line after cleaning: 'O'
# train.txt:16775: ❌ Malformed line after cleaning: 'O'
# train.txt:16801: ❌ Malformed line after cleaning: 'O'
# train.txt:16803: ❌ Malformed line after cleaning: 'O'
# train.txt:17001: ❌ Malformed line after cleaning: 'O'
# train.txt:17005: ❌ Malformed line after cleaning: 'O'
# train.txt:17065: ❌ Malformed line after cleaning: 'O'
# train.txt:17067: ❌ Malformed line after cleaning: 'O'
# train.txt:17071: ❌ Malformed line after cleaning: 'O'
# train.txt:17074: ❌ Malformed line after cleaning: 'O'
# train.txt:17105: ❌ Malformed line after cleaning: 'O'
# train.txt:17285: ❌ Malformed line after cleaning: 'O'
# train.txt:17286: ❌ Malformed line after cleaning: 'O'
# train.txt:17291: ❌ Malformed line after cleaning: 'O'
# train.txt:17295: ❌ Malformed line after cleaning: 'O'
# train.txt:17296: ❌ Malformed line after cleaning: 'O'
# train.txt:17298: ❌ Malformed line after cleaning: 'O'
# train.txt:17367: ❌ Malformed line after cleaning: 'O'
# train.txt:17370: ❌ Malformed line after cleaning: 'O'
# train.txt:17375: ❌ Malformed line after cleaning: 'O'
# train.txt:17379: ❌ Malformed line after cleaning: 'O'
# train.txt:18114: ❌ Malformed line after cleaning: 'O'
# train.txt:18119: ❌ Malformed line after cleaning: 'O'
# train.txt:18120: ❌ Malformed line after cleaning: 'O'
# train.txt:18122: ❌ Malformed line after cleaning: 'O'
# train.txt:18127: ❌ Malformed line after cleaning: 'O'
# train.txt:18130: ❌ Malformed line after cleaning: 'O'
# train.txt:18150: ❌ Malformed line after cleaning: 'O'
# train.txt:18153: ❌ Malformed line after cleaning: 'O'
# train.txt:18324: ❌ Malformed line after cleaning: 'O'
# train.txt:18327: ❌ Malformed line after cleaning: 'O'
# train.txt:18396: ❌ Malformed line after cleaning: 'O'
# train.txt:18399: ❌ Malformed line after cleaning: 'O'
# train.txt:18431: ❌ Malformed line after cleaning: 'O'
# train.txt:18775: ❌ Malformed line after cleaning: 'O'
# train.txt:18779: ❌ Malformed line after cleaning: 'O'
# train.txt:18780: ❌ Malformed line after cleaning: 'O'
# train.txt:18782: ❌ Malformed line after cleaning: 'O'
# train.txt:18786: ❌ Malformed line after cleaning: 'O'
# train.txt:18789: ❌ Malformed line after cleaning: 'O'
# train.txt:18902: ❌ Malformed line after cleaning: 'O'
# train.txt:18904: ❌ Malformed line after cleaning: 'O'
# train.txt:18909: ❌ Malformed line after cleaning: 'O'
# train.txt:18913: ❌ Malformed line after cleaning: 'O'
# train.txt:19182: ❌ Malformed line after cleaning: 'O'
# train.txt:19186: ❌ Malformed line after cleaning: 'O'
# train.txt:19224: ❌ Malformed line after cleaning: 'O'
# train.txt:19228: ❌ Malformed line after cleaning: 'O'
# train.txt:19229: ❌ Malformed line after cleaning: 'O'
# train.txt:19231: ❌ Malformed line after cleaning: 'O'
# train.txt:19232: ❌ Malformed line after cleaning: 'O'
# train.txt:19236: ❌ Malformed line after cleaning: 'O'
# train.txt:19530: ❌ Malformed line after cleaning: 'O'
# train.txt:19532: ❌ Malformed line after cleaning: 'O'
# train.txt:19538: ❌ Malformed line after cleaning: 'O'
# train.txt:19542: ❌ Malformed line after cleaning: 'O'
# train.txt:19769: ❌ Malformed line after cleaning: 'O'
# train.txt:19771: ❌ Malformed line after cleaning: 'O'
# train.txt:19776: ❌ Malformed line after cleaning: 'O'
# train.txt:19780: ❌ Malformed line after cleaning: 'O'
# train.txt:20128: ❌ Malformed line after cleaning: 'O'
# train.txt:20132: ❌ Malformed line after cleaning: 'O'
# train.txt:20147: ❌ Malformed line after cleaning: 'O'
# train.txt:20149: ❌ Malformed line after cleaning: 'O'
# train.txt:20151: ❌ Malformed line after cleaning: 'O'
# train.txt:20155: ❌ Malformed line after cleaning: 'O'
# train.txt:20205: ❌ Malformed line after cleaning: 'O'
# train.txt:20207: ❌ Malformed line after cleaning: 'O'
# train.txt:20209: ❌ Malformed line after cleaning: 'O'
# train.txt:20213: ❌ Malformed line after cleaning: 'O'
# train.txt:20214: ❌ Malformed line after cleaning: 'O'
# train.txt:20216: ❌ Malformed line after cleaning: 'O'
# train.txt:20288: ❌ Malformed line after cleaning: 'O'
# train.txt:20292: ❌ Malformed line after cleaning: 'O'
# train.txt:20382: ❌ Malformed line after cleaning: 'O'
# train.txt:20388: ❌ Malformed line after cleaning: 'O'
# train.txt:20389: ❌ Malformed line after cleaning: 'O'
# train.txt:20391: ❌ Malformed line after cleaning: 'O'
# train.txt:20441: ❌ Malformed line after cleaning: 'O'
# train.txt:20443: ❌ Malformed line after cleaning: 'O'
# train.txt:20448: ❌ Malformed line after cleaning: 'O'
# train.txt:20451: ❌ Malformed line after cleaning: 'O'
# train.txt:20452: ❌ Malformed line after cleaning: 'O'
# train.txt:20455: ❌ Malformed line after cleaning: 'O'
# train.txt:20693: ❌ Malformed line after cleaning: 'O'
# train.txt:20695: ❌ Malformed line after cleaning: 'O'
# train.txt:20700: ❌ Malformed line after cleaning: 'O'
# train.txt:20704: ❌ Malformed line after cleaning: 'O'
# train.txt:20782: ❌ Malformed line after cleaning: 'O'
# train.txt:20786: ❌ Malformed line after cleaning: 'O'
# train.txt:20787: ❌ Malformed line after cleaning: 'O'
# train.txt:20789: ❌ Malformed line after cleaning: 'O'
# train.txt:20790: ❌ Malformed line after cleaning: 'O'
# train.txt:20793: ❌ Malformed line after cleaning: 'O'
# train.txt:20802: ❌ Malformed line after cleaning: 'O'
# train.txt:21061: ❌ Malformed line after cleaning: 'O'
# train.txt:21065: ❌ Malformed line after cleaning: 'O'
# train.txt:21066: ❌ Malformed line after cleaning: 'O'
# train.txt:21068: ❌ Malformed line after cleaning: 'O'
# train.txt:21069: ❌ Malformed line after cleaning: 'O'
# train.txt:21072: ❌ Malformed line after cleaning: 'O'
# train.txt:21158: ❌ Malformed line after cleaning: 'O'
# train.txt:21162: ❌ Malformed line after cleaning: 'O'
# train.txt:21163: ❌ Malformed line after cleaning: 'O'
# train.txt:21165: ❌ Malformed line after cleaning: 'O'
# train.txt:21209: ❌ Malformed line after cleaning: 'O'
# train.txt:21545: ❌ Malformed line after cleaning: 'O'
# train.txt:21558: ❌ Malformed line after cleaning: 'O'
# train.txt:21560: ❌ Malformed line after cleaning: 'O'
# train.txt:21566: ❌ Malformed line after cleaning: 'O'
# train.txt:21570: ❌ Malformed line after cleaning: 'O'
# train.txt:21653: ❌ Malformed line after cleaning: 'O'
# train.txt:21793: ❌ Malformed line after cleaning: 'O'
# train.txt:21795: ❌ Malformed line after cleaning: 'O'
# train.txt:21797: ❌ Malformed line after cleaning: 'O'
# train.txt:21799: ❌ Malformed line after cleaning: 'O'
# train.txt:21803: ❌ Malformed line after cleaning: 'O'
# train.txt:21804: ❌ Malformed line after cleaning: 'O'
# train.txt:21806: ❌ Malformed line after cleaning: 'O'
# train.txt:21807: ❌ Malformed line after cleaning: 'O'
# train.txt:21811: ❌ Malformed line after cleaning: 'O'
# train.txt:21871: ❌ Malformed line after cleaning: 'O'
# train.txt:21873: ❌ Malformed line after cleaning: 'O'
# train.txt:21878: ❌ Malformed line after cleaning: 'O'
# train.txt:21884: ❌ Malformed line after cleaning: 'O'
# train.txt:22174: ❌ Malformed line after cleaning: 'O'
# train.txt:22178: ❌ Malformed line after cleaning: 'O'
# train.txt:22182: ❌ Malformed line after cleaning: 'O'
# train.txt:22266: ❌ Malformed line after cleaning: 'O'
# train.txt:22338: ❌ Malformed line after cleaning: 'O'
# train.txt:22448: ❌ Malformed line after cleaning: 'O'
# train.txt:22452: ❌ Malformed line after cleaning: 'O'
# train.txt:22453: ❌ Malformed line after cleaning: 'O'
# train.txt:22455: ❌ Malformed line after cleaning: 'O'
# train.txt:22456: ❌ Malformed line after cleaning: 'O'
# train.txt:22461: ❌ Malformed line after cleaning: 'O'
# train.txt:22521: ❌ Malformed line after cleaning: 'O'
# train.txt:22523: ❌ Malformed line after cleaning: 'O'
# train.txt:22539: ❌ Malformed line after cleaning: 'O'
# train.txt:22543: ❌ Malformed line after cleaning: 'O'
# train.txt:22710: ❌ Malformed line after cleaning: 'O'
# train.txt:23761: ❌ Malformed line after cleaning: 'O'
# train.txt:25422: ❌ Malformed line after cleaning: 'O'
# train.txt:25504: ❌ Malformed line after cleaning: 'O'
# train.txt:25577: ❌ Malformed line after cleaning: 'O'
# train.txt:28194: ❌ Malformed line after cleaning: 'O'
# train.txt:29243: ❌ Malformed line after cleaning: 'O'
# train.txt:31773: ❌ Malformed line after cleaning: 'O'
# train.txt:34343: ❌ Malformed line after cleaning: 'O'
# train.txt:34640: ❌ Malformed line after cleaning: 'O'
# train.txt:34969: ❌ Malformed line after cleaning: 'O'
# train.txt:35735: ❌ Malformed line after cleaning: 'O'
# train.txt:39100: ❌ Malformed line after cleaning: 'O'
# train.txt:39108: ❌ Malformed line after cleaning: 'O'
# train.txt:39692: ❌ Malformed line after cleaning: 'O'
# train.txt:40243: ❌ Malformed line after cleaning: 'O'
# train.txt:40244: ❌ Malformed line after cleaning: 'O'
# train.txt:41072: ❌ Malformed line after cleaning: 'O'
# train.txt:41079: ❌ Malformed line after cleaning: 'O'
# train.txt:43970: ❌ Malformed line after cleaning: 'O'
# train.txt:43977: ❌ Malformed line after cleaning: 'O'
# train.txt:44735: ❌ Malformed line after cleaning: 'O'
# train.txt:45352: ❌ Malformed line after cleaning: 'O'
# train.txt:45816: ❌ Malformed line after cleaning: 'O'
# train.txt:46472: ❌ Malformed line after cleaning: 'O'
# train.txt:46949: ❌ Malformed line after cleaning: 'O'
# train.txt:46960: ❌ Malformed line after cleaning: 'O'
# train.txt:46961: ❌ Malformed line after cleaning: 'O'
# train.txt:46965: ❌ Malformed line after cleaning: 'O'
# train.txt:47373: ❌ Malformed line after cleaning: 'O'
# train.txt:47377: ❌ Malformed line after cleaning: 'O'
# train.txt:47393: ❌ Malformed line after cleaning: 'O'
# train.txt:47397: ❌ Malformed line after cleaning: 'O'
# train.txt:47491: ❌ Malformed line after cleaning: 'O'
# train.txt:47498: ❌ Malformed line after cleaning: 'O'
# train.txt:47507: ❌ Malformed line after cleaning: 'O'
# train.txt:47510: ❌ Malformed line after cleaning: 'O'
# train.txt:47513: ❌ Malformed line after cleaning: 'O'
# train.txt:47567: ❌ Malformed line after cleaning: 'O'
# train.txt:47605: ❌ Malformed line after cleaning: 'O'
# train.txt:47640: ❌ Malformed line after cleaning: 'O'
# train.txt:47644: ❌ Malformed line after cleaning: 'O'
# train.txt:47699: ❌ Malformed line after cleaning: 'O'
# train.txt:47714: ❌ Malformed line after cleaning: 'O'
# train.txt:47834: ❌ Malformed line after cleaning: 'O'
# train.txt:47842: ❌ Malformed line after cleaning: 'O'
# train.txt:48226: ❌ Malformed line after cleaning: 'O'
# train.txt:48530: ❌ Malformed line after cleaning: 'O'
# train.txt:48586: ❌ Malformed line after cleaning: 'O'
# train.txt:48872: ❌ Malformed line after cleaning: 'O'
# train.txt:48880: ❌ Malformed line after cleaning: 'O'
# train.txt:48886: ❌ Malformed line after cleaning: 'O'
# train.txt:48889: ❌ Malformed line after cleaning: 'O'
# train.txt:48985: ❌ Malformed line after cleaning: 'O'
# train.txt:48989: ❌ Malformed line after cleaning: 'O'
# train.txt:49384: ❌ Malformed line after cleaning: 'O'
# train.txt:49464: ❌ Malformed line after cleaning: 'O'
# train.txt:49471: ❌ Malformed line after cleaning: 'O'
# train.txt:49770: ❌ Malformed line after cleaning: 'O'
# train.txt:49791: ❌ Malformed line after cleaning: 'O'
# train.txt:49797: ❌ Malformed line after cleaning: 'O'
# train.txt:49881: ❌ Malformed line after cleaning: 'O'
# train.txt:49888: ❌ Malformed line after cleaning: 'O'
# train.txt:50460: ❌ Malformed line after cleaning: 'O'
# train.txt:50464: ❌ Malformed line after cleaning: 'O'
# train.txt:50792: ❌ Malformed line after cleaning: 'O'
# train.txt:50869: ❌ Malformed line after cleaning: 'O'
# train.txt:50970: ❌ Malformed line after cleaning: 'O'
# train.txt:50974: ❌ Malformed line after cleaning: 'O'
# train.txt:51185: ❌ Malformed line after cleaning: 'O'
# train.txt:51195: ❌ Malformed line after cleaning: 'O'
# train.txt:51501: ❌ Malformed line after cleaning: 'O'
# train.txt:51505: ❌ Malformed line after cleaning: 'O'
# train.txt:51580: ❌ Malformed line after cleaning: 'O'
# train.txt:51584: ❌ Malformed line after cleaning: 'O'
# train.txt:51597: ❌ Malformed line after cleaning: 'O'
# train.txt:51601: ❌ Malformed line after cleaning: 'O'
# train.txt:51653: ❌ Malformed line after cleaning: 'O'
# train.txt:51658: ❌ Malformed line after cleaning: 'O'
# train.txt:51675: ❌ Malformed line after cleaning: 'O'
# train.txt:51744: ❌ Malformed line after cleaning: 'O'
# train.txt:51750: ❌ Malformed line after cleaning: 'O'
# train.txt:51774: ❌ Malformed line after cleaning: 'O'
# train.txt:51788: ❌ Malformed line after cleaning: 'O'
# train.txt:51841: ❌ Malformed line after cleaning: 'O'
# train.txt:51957: ❌ Malformed line after cleaning: 'O'
# train.txt:51998: ❌ Malformed line after cleaning: 'O'
# train.txt:52002: ❌ Malformed line after cleaning: 'O'
# train.txt:52165: ❌ Malformed line after cleaning: 'O'
# train.txt:52175: ❌ Malformed line after cleaning: 'O'
# train.txt:52421: ❌ Malformed line after cleaning: 'O'
# train.txt:52998: ❌ Malformed line after cleaning: 'O'
# train.txt:53023: ❌ Malformed line after cleaning: 'O'
# train.txt:53026: ❌ Malformed line after cleaning: 'O'
# train.txt:53055: ❌ Malformed line after cleaning: 'O'
# train.txt:53139: ❌ Malformed line after cleaning: 'O'
# train.txt:53258: ❌ Malformed line after cleaning: 'O'
# train.txt:53266: ❌ Malformed line after cleaning: 'O'
# train.txt:53323: ❌ Malformed line after cleaning: 'O'
# train.txt:53335: ❌ Malformed line after cleaning: 'O'
# train.txt:53421: ❌ Malformed line after cleaning: 'O'
# train.txt:53425: ❌ Malformed line after cleaning: 'O'
# train.txt:53541: ❌ Malformed line after cleaning: 'O'
# train.txt:53545: ❌ Malformed line after cleaning: 'O'
# train.txt:53546: ❌ Malformed line after cleaning: 'O'
# train.txt:53625: ❌ Malformed line after cleaning: 'O'
# train.txt:53655: ❌ Malformed line after cleaning: 'O'
# train.txt:53722: ❌ Malformed line after cleaning: 'O'
# train.txt:53802: ❌ Malformed line after cleaning: 'O'
# train.txt:54129: ❌ Malformed line after cleaning: 'O'
# train.txt:54137: ❌ Malformed line after cleaning: 'O'
# train.txt:54478: ❌ Malformed line after cleaning: 'O'
# train.txt:54619: ❌ Malformed line after cleaning: 'O'
# train.txt:54627: ❌ Malformed line after cleaning: 'O'
# train.txt:54634: ❌ Malformed line after cleaning: 'O'
# train.txt:54638: ❌ Malformed line after cleaning: 'O'
# train.txt:54646: ❌ Malformed line after cleaning: 'O'
# train.txt:54650: ❌ Malformed line after cleaning: 'O'
# train.txt:54771: ❌ Malformed line after cleaning: 'O'
# train.txt:54773: ❌ Malformed line after cleaning: 'O'
# train.txt:54779: ❌ Malformed line after cleaning: 'O'
# train.txt:54808: ❌ Malformed line after cleaning: 'O'
# train.txt:54812: ❌ Malformed line after cleaning: 'O'
# train.txt:55257: ❌ Malformed line after cleaning: 'O'
# train.txt:55263: ❌ Malformed line after cleaning: 'O'
# train.txt:55610: ❌ Malformed line after cleaning: 'O'
# train.txt:55924: ❌ Malformed line after cleaning: 'O'
# train.txt:55929: ❌ Malformed line after cleaning: 'O'
# train.txt:56233: ❌ Malformed line after cleaning: 'O'
# train.txt:56238: ❌ Malformed line after cleaning: 'O'
# train.txt:56259: ❌ Malformed line after cleaning: 'O'
# train.txt:56263: ❌ Malformed line after cleaning: 'O'
# train.txt:56284: ❌ Malformed line after cleaning: 'O'
# train.txt:56288: ❌ Malformed line after cleaning: 'O'
# train.txt:56355: ❌ Malformed line after cleaning: 'O'
# train.txt:56359: ❌ Malformed line after cleaning: 'O'
# train.txt:56360: ❌ Malformed line after cleaning: 'O'
# train.txt:56364: ❌ Malformed line after cleaning: 'O'
# train.txt:56441: ❌ Malformed line after cleaning: 'O'
# train.txt:56445: ❌ Malformed line after cleaning: 'O'
# train.txt:56494: ❌ Malformed line after cleaning: 'O'
# train.txt:56499: ❌ Malformed line after cleaning: 'O'
# train.txt:56583: ❌ Malformed line after cleaning: 'O'
# train.txt:56594: ❌ Malformed line after cleaning: 'O'
# train.txt:56649: ❌ Malformed line after cleaning: 'O'
# train.txt:56653: ❌ Malformed line after cleaning: 'O'
# train.txt:56676: ❌ Malformed line after cleaning: 'O'
# train.txt:56680: ❌ Malformed line after cleaning: 'O'
# train.txt:56703: ❌ Malformed line after cleaning: 'O'
# train.txt:56707: ❌ Malformed line after cleaning: 'O'
# train.txt:56736: ❌ Malformed line after cleaning: 'O'
# train.txt:56740: ❌ Malformed line after cleaning: 'O'
# train.txt:56773: ❌ Malformed line after cleaning: 'O'
# train.txt:56777: ❌ Malformed line after cleaning: 'O'
# train.txt:56778: ❌ Malformed line after cleaning: 'O'
# train.txt:56782: ❌ Malformed line after cleaning: 'O'
# train.txt:56788: ❌ Malformed line after cleaning: 'O'
# train.txt:56792: ❌ Malformed line after cleaning: 'O'
# train.txt:56798: ❌ Malformed line after cleaning: 'O'
# train.txt:56808: ❌ Malformed line after cleaning: 'O'
# train.txt:56843: ❌ Malformed line after cleaning: 'O'
# train.txt:56921: ❌ Malformed line after cleaning: 'O'
# train.txt:56928: ❌ Malformed line after cleaning: 'O'
# train.txt:56934: ❌ Malformed line after cleaning: 'O'
# train.txt:56968: ❌ Malformed line after cleaning: 'O'
# train.txt:56982: ❌ Malformed line after cleaning: 'O'
# train.txt:57130: ❌ Malformed line after cleaning: 'O'
# train.txt:57136: ❌ Malformed line after cleaning: 'O'
# train.txt:57573: ❌ Malformed line after cleaning: 'O'
# train.txt:57594: ❌ Malformed line after cleaning: 'O'
# train.txt:57846: ❌ Malformed line after cleaning: 'O'
# train.txt:58139: ❌ Malformed line after cleaning: 'O'
# train.txt:58226: ❌ Malformed line after cleaning: 'O'
# train.txt:58236: ❌ Malformed line after cleaning: 'O'
# train.txt:58463: ❌ Malformed line after cleaning: 'O'
# train.txt:58470: ❌ Malformed line after cleaning: 'O'
# train.txt:58587: ❌ Malformed line after cleaning: 'O'
# train.txt:58591: ❌ Malformed line after cleaning: 'O'
# train.txt:58743: ❌ Malformed line after cleaning: 'O'
# train.txt:58748: ❌ Malformed line after cleaning: 'O'
# train.txt:58777: ❌ Malformed line after cleaning: 'O'
# train.txt:58786: ❌ Malformed line after cleaning: 'O'
# train.txt:58842: ❌ Malformed line after cleaning: 'O'
# train.txt:59213: ❌ Malformed line after cleaning: 'O'
# train.txt:59220: ❌ Malformed line after cleaning: 'O'
# train.txt:59448: ❌ Malformed line after cleaning: 'O'
# train.txt:59452: ❌ Malformed line after cleaning: 'O'
# train.txt:59517: ❌ Malformed line after cleaning: 'O'
# train.txt:59530: ❌ Malformed line after cleaning: 'O'
# train.txt:59611: ❌ Malformed line after cleaning: 'O'
# train.txt:59615: ❌ Malformed line after cleaning: 'O'
# train.txt:59664: ❌ Malformed line after cleaning: 'O'
# train.txt:59672: ❌ Malformed line after cleaning: 'O'
# train.txt:59873: ❌ Malformed line after cleaning: 'O'
# train.txt:59877: ❌ Malformed line after cleaning: 'O'
# train.txt:59954: ❌ Malformed line after cleaning: 'O'
# train.txt:59959: ❌ Malformed line after cleaning: 'O'
# train.txt:60113: ❌ Malformed line after cleaning: 'O'
# train.txt:60129: ❌ Malformed line after cleaning: 'O'
# train.txt:63157: ❌ Malformed line after cleaning: 'O'
# train.txt:63282: ❌ Malformed line after cleaning: 'O'
# train.txt:63345: ❌ Malformed line after cleaning: 'O'
# train.txt:63421: ❌ Malformed line after cleaning: 'O'
# train.txt:67815: ❌ Malformed line after cleaning: 'O'
# train.txt:69202: ❌ Malformed line after cleaning: 'O'
# train.txt:69208: ❌ Malformed line after cleaning: 'O'
# train.txt:69214: ❌ Malformed line after cleaning: 'O'
# train.txt:69298: ❌ Malformed line after cleaning: 'O'
# train.txt:69583: ❌ Malformed line after cleaning: 'O'
# train.txt:69589: ❌ Malformed line after cleaning: 'O'
# train.txt:70135: ❌ Malformed line after cleaning: 'O'
# train.txt:70142: ❌ Malformed line after cleaning: 'O'
# train.txt:70152: ❌ Malformed line after cleaning: 'O'
# train.txt:73307: ❌ Malformed line after cleaning: 'O'
# train.txt:73364: ❌ Malformed line after cleaning: 'O'
# train.txt:73374: ❌ Malformed line after cleaning: 'O'
# train.txt:73474: ❌ Malformed line after cleaning: 'O'
# train.txt:73489: ❌ Malformed line after cleaning: 'O'
# train.txt:73574: ❌ Malformed line after cleaning: 'O'
# train.txt:75034: ❌ Malformed line after cleaning: 'O'
# train.txt:75067: ❌ Malformed line after cleaning: 'O'
# train.txt:75087: ❌ Malformed line after cleaning: 'O'
# train.txt:75115: ❌ Malformed line after cleaning: 'O'
# train.txt:75176: ❌ Malformed line after cleaning: 'O'
# train.txt:75177: ❌ Malformed line after cleaning: 'O'
# train.txt:75358: ❌ Malformed line after cleaning: 'O'
# train.txt:75371: ❌ Malformed line after cleaning: 'O'
# train.txt:77322: ❌ Malformed line after cleaning: 'O'
# train.txt:77341: ❌ Malformed line after cleaning: 'O'
# train.txt:77355: ❌ Malformed line after cleaning: 'O'
# train.txt:77366: ❌ Malformed line after cleaning: 'O'
# train.txt:77384: ❌ Malformed line after cleaning: 'O'
# train.txt:77476: ❌ Malformed line after cleaning: 'O'
# train.txt:97712: ❌ Malformed line after cleaning: 'O'
# train.txt:106811: ❌ Malformed line after cleaning: 'O'
# train.txt:107579: ❌ Malformed line after cleaning: 'O'
# train.txt:107686: ❌ Malformed line after cleaning: 'O'
# train.txt:108345: ❌ Malformed line after cleaning: 'O'
# train.txt:108859: ❌ Malformed line after cleaning: 'O'
# train.txt:109381: ❌ Malformed line after cleaning: 'O'
# train.txt:109387: ❌ Malformed line after cleaning: 'O'
# train.txt:109536: ❌ Malformed line after cleaning: 'O'
# train.txt:110048: ❌ Malformed line after cleaning: 'O'
# train.txt:110378: ❌ Malformed line after cleaning: 'O'
# train.txt:110437: ❌ Malformed line after cleaning: 'O'
# train.txt:110500: ❌ Malformed line after cleaning: 'O'
# train.txt:110660: ❌ Malformed line after cleaning: 'O'
# train.txt:110938: ❌ Malformed line after cleaning: 'O'
# train.txt:111070: ❌ Malformed line after cleaning: 'O'
# train.txt:111175: ❌ Malformed line after cleaning: 'O'
# train.txt:112900: ❌ Malformed line after cleaning: 'O'
# train.txt:113848: ❌ Malformed line after cleaning: 'O'
# train.txt:113850: ❌ Malformed line after cleaning: 'O'
# train.txt:114036: ❌ Malformed line after cleaning: 'O'
# train.txt:114046: ❌ Malformed line after cleaning: 'O'
# train.txt:114503: ❌ Malformed line after cleaning: 'O'
# train.txt:114805: ❌ Malformed line after cleaning: 'O'
# train.txt:116221: ❌ Malformed line after cleaning: 'O'
# train.txt:116222: ❌ Malformed line after cleaning: 'O'
# train.txt:117544: ❌ Malformed line after cleaning: 'O'
# train.txt:117610: ❌ Malformed line after cleaning: 'O'
# train.txt:117767: ❌ Malformed line after cleaning: 'O'
# train.txt:117858: ❌ Malformed line after cleaning: 'O'
# train.txt:117862: ❌ Malformed line after cleaning: 'O'
# train.txt:118484: ❌ Malformed line after cleaning: 'O'
# train.txt:119426: ❌ Malformed line after cleaning: 'O'
# train.txt:122786: ❌ Malformed line after cleaning: 'O'
# train.txt:124062: ❌ Malformed line after cleaning: 'O'
# train.txt:124432: ❌ Malformed line after cleaning: 'O'
# train.txt:124541: ❌ Malformed line after cleaning: 'O'
# train.txt:124542: ❌ Malformed line after cleaning: 'O'
# train.txt:126993: ❌ Malformed line after cleaning: 'O'
# train.txt:127222: ❌ Malformed line after cleaning: 'O'
# train.txt:127317: ❌ Malformed line after cleaning: 'O'
# train.txt:127326: ❌ Malformed line after cleaning: 'O'
# train.txt:127983: ❌ Malformed line after cleaning: 'O'
# train.txt:128840: ❌ Malformed line after cleaning: 'O'
# train.txt:133341: ❌ Malformed line after cleaning: 'O'
# train.txt:133762: ❌ Malformed line after cleaning: 'O'
# train.txt:136367: ❌ Malformed line after cleaning: 'O'
# train.txt:137239: ❌ Malformed line after cleaning: 'O'
# train.txt:138254: ❌ Malformed line after cleaning: 'O'
# train.txt:138488: ❌ Malformed line after cleaning: 'O'
# train.txt:138529: ❌ Malformed line after cleaning: 'O'
# train.txt:139300: ❌ Malformed line after cleaning: 'O'
# train.txt:142008: ❌ Malformed line after cleaning: 'O'
# train.txt:142727: ❌ Malformed line after cleaning: 'O'
# train.txt:143199: ❌ Malformed line after cleaning: 'O'
# train.txt:143253: ❌ Malformed line after cleaning: 'O'
# train.txt:143280: ❌ Malformed line after cleaning: 'O'
# train.txt:143393: ❌ Malformed line after cleaning: 'O'
# train.txt:143400: ❌ Malformed line after cleaning: 'O'
# train.txt:143574: ❌ Malformed line after cleaning: 'O'
# train.txt:143740: ❌ Malformed line after cleaning: 'O'
# train.txt:143918: ❌ Malformed line after cleaning: 'O'
# train.txt:144832: ❌ Malformed line after cleaning: 'O'
# train.txt:144837: ❌ Malformed line after cleaning: 'O'
# train.txt:144843: ❌ Malformed line after cleaning: 'O'
# train.txt:145051: ❌ Malformed line after cleaning: 'O'
# train.txt:145059: ❌ Malformed line after cleaning: 'O'
# train.txt:145702: ❌ Malformed line after cleaning: 'O'
# train.txt:145858: ❌ Malformed line after cleaning: 'O'
# train.txt:145982: ❌ Malformed line after cleaning: 'O'
# train.txt:147865: ❌ Malformed line after cleaning: 'O'
# train.txt:147870: ❌ Malformed line after cleaning: 'O'
# train.txt:148529: ❌ Malformed line after cleaning: 'O'
# train.txt:148541: ❌ Malformed line after cleaning: 'O'
# train.txt:148607: ❌ Malformed line after cleaning: 'O'
# train.txt:148613: ❌ Malformed line after cleaning: 'O'
# train.txt:148629: ❌ Malformed line after cleaning: 'O'
# train.txt:148662: ❌ Malformed line after cleaning: 'O'
# train.txt:148684: ❌ Malformed line after cleaning: 'O'
# train.txt:149305: ❌ Malformed line after cleaning: 'O'
# train.txt:149325: ❌ Malformed line after cleaning: 'O'
# train.txt:150820: ❌ Malformed line after cleaning: 'O'
# train.txt:151584: ❌ Malformed line after cleaning: 'O'
# train.txt:152188: ❌ Malformed line after cleaning: 'O'
# train.txt:152200: ❌ Malformed line after cleaning: 'O'
# train.txt:152289: ❌ Malformed line after cleaning: 'O'
# train.txt:152295: ❌ Malformed line after cleaning: 'O'
# train.txt:152370: ❌ Malformed line after cleaning: 'O'
# train.txt:152508: ❌ Malformed line after cleaning: 'O'
# train.txt:152512: ❌ Malformed line after cleaning: 'O'
# train.txt:152549: ❌ Malformed line after cleaning: 'O'
# train.txt:152562: ❌ Malformed line after cleaning: 'O'
# train.txt:152899: ❌ Malformed line after cleaning: 'O'
# train.txt:153210: ❌ Malformed line after cleaning: 'O'
# train.txt:153691: ❌ Malformed line after cleaning: 'O'
# train.txt:154340: ❌ Malformed line after cleaning: 'O'
# train.txt:154348: ❌ Malformed line after cleaning: 'O'
# train.txt:154349: ❌ Malformed line after cleaning: 'O'
# train.txt:154353: ❌ Malformed line after cleaning: 'O'
# train.txt:154466: ❌ Malformed line after cleaning: 'O'
# train.txt:155463: ❌ Malformed line after cleaning: 'O'
# train.txt:155717: ❌ Malformed line after cleaning: 'O'
# train.txt:155721: ❌ Malformed line after cleaning: 'O'
# train.txt:156599: ❌ Malformed line after cleaning: 'O'
# train.txt:156615: ❌ Malformed line after cleaning: 'O'
# train.txt:157044: ❌ Malformed line after cleaning: 'O'
# train.txt:157118: ❌ Malformed line after cleaning: 'O'
# train.txt:157148: ❌ Malformed line after cleaning: 'O'
# train.txt:157713: ❌ Malformed line after cleaning: 'O'
# train.txt:157717: ❌ Malformed line after cleaning: 'O'
# train.txt:157787: ❌ Malformed line after cleaning: 'O'
# train.txt:157797: ❌ Malformed line after cleaning: 'O'
# train.txt:158021: ❌ Malformed line after cleaning: 'O'
# train.txt:158504: ❌ Malformed line after cleaning: 'O'
# train.txt:158729: ❌ Malformed line after cleaning: 'O'
# train.txt:158733: ❌ Malformed line after cleaning: 'O'
# train.txt:158807: ❌ Malformed line after cleaning: 'O'
# train.txt:159118: ❌ Malformed line after cleaning: 'O'
# train.txt:159134: ❌ Malformed line after cleaning: 'O'
# train.txt:159578: ❌ Malformed line after cleaning: 'O'
# train.txt:159582: ❌ Malformed line after cleaning: 'O'
# train.txt:159765: ❌ Malformed line after cleaning: 'O'
# train.txt:159769: ❌ Malformed line after cleaning: 'O'
# train.txt:160075: ❌ Malformed line after cleaning: 'O'
# train.txt:160140: ❌ Malformed line after cleaning: 'O'
# train.txt:160149: ❌ Malformed line after cleaning: 'O'
# train.txt:160401: ❌ Malformed line after cleaning: 'O'
# train.txt:160424: ❌ Malformed line after cleaning: 'O'
# train.txt:160473: ❌ Malformed line after cleaning: 'O'
# train.txt:160530: ❌ Malformed line after cleaning: 'O'
# train.txt:160969: ❌ Malformed line after cleaning: 'O'
# train.txt:160973: ❌ Malformed line after cleaning: 'O'
# train.txt:161414: ❌ Malformed line after cleaning: 'O'
# train.txt:161452: ❌ Malformed line after cleaning: 'O'
# train.txt:161828: ❌ Malformed line after cleaning: 'O'
# train.txt:161832: ❌ Malformed line after cleaning: 'O'
# train.txt:161875: ❌ Malformed line after cleaning: 'O'
# train.txt:161953: ❌ Malformed line after cleaning: 'O'
# train.txt:161957: ❌ Malformed line after cleaning: 'O'
# train.txt:162072: ❌ Malformed line after cleaning: 'O'
# train.txt:162404: ❌ Malformed line after cleaning: 'O'
# train.txt:162408: ❌ Malformed line after cleaning: 'O'
# train.txt:162459: ❌ Malformed line after cleaning: 'O'
# train.txt:162542: ❌ Malformed line after cleaning: 'O'
# train.txt:162588: ❌ Malformed line after cleaning: 'O'
# train.txt:162862: ❌ Malformed line after cleaning: 'O'
# train.txt:162867: ❌ Malformed line after cleaning: 'O'
# train.txt:162897: ❌ Malformed line after cleaning: 'O'
# train.txt:162902: ❌ Malformed line after cleaning: 'O'
# train.txt:162994: ❌ Malformed line after cleaning: 'O'
# train.txt:162998: ❌ Malformed line after cleaning: 'O'
# train.txt:163203: ❌ Malformed line after cleaning: 'O'
# train.txt:163426: ❌ Malformed line after cleaning: 'O'
# train.txt:163570: ❌ Malformed line after cleaning: 'O'
# train.txt:163908: ❌ Malformed line after cleaning: 'O'
# train.txt:164544: ❌ Malformed line after cleaning: 'O'
# train.txt:164789: ❌ Malformed line after cleaning: 'O'
# train.txt:165257: ❌ Malformed line after cleaning: 'O'
# train.txt:165276: ❌ Malformed line after cleaning: 'O'
# ...
# train.txt:172290: ❌ Malformed line after cleaning: 'O'
# train.txt:172497: ❌ Malformed line after cleaning: 'O'
# train.txt:172706: ❌ Malformed line after cleaning: 'O'
# train.txt:172768: ❌ Malformed line after cleaning: 'O'
# train.txt:172835: ❌ Malformed line after cleaning: 'O'
# train.txt:172840: ❌ Malformed line after cleaning: 'O'
# train.txt:173124: ❌ Malformed line after cleaning: 'O'
# train.txt:173400: ❌ Malformed line after cleaning: 'O'
# train.txt:173587: ❌ Malformed line after cleaning: 'O'
# train.txt:173734: ❌ Malformed line after cleaning: 'O'
# train.txt:173873: ❌ Malformed line after cleaning: 'O'
# train.txt:173879: ❌ Malformed line after cleaning: 'O'
# train.txt:174160: ❌ Malformed line after cleaning: 'O'
# train.txt:174164: ❌ Malformed line after cleaning: 'O'
# train.txt:174186: ❌ Malformed line after cleaning: 'O'
# train.txt:174249: ❌ Malformed line after cleaning: 'O'
# train.txt:174277: ❌ Malformed line after cleaning: 'O'
# train.txt:174491: ❌ Malformed line after cleaning: 'O'
# train.txt:174617: ❌ Malformed line after cleaning: 'O'
# train.txt:174709: ❌ Malformed line after cleaning: 'O'
# train.txt:175018: ❌ Malformed line after cleaning: 'O'
# train.txt:175024: ❌ Malformed line after cleaning: 'O'
# train.txt:175164: ❌ Malformed line after cleaning: 'O'
#
# 📂 Validating file: dev.txt
# ------------------------------------------------------------
# dev.txt:3: ⚠️ Empty sentence block detected. Context:
# ---
# Acto O
# ---
#
# dev.txt:4: ⚠️ Empty sentence block detected. Context:
# ---
# Acto O
# ---
#
# dev.txt:541: ❌ Malformed line after cleaning: 'O'
# dev.txt:555: ❌ Malformed line after cleaning: 'O'
# dev.txt:609: ❌ Malformed line after cleaning: 'O'
# dev.txt:624: ❌ Malformed line after cleaning: 'O'
# dev.txt:638: ❌ Malformed line after cleaning: 'O'
# dev.txt:702: ❌ Malformed line after cleaning: 'O'
# dev.txt:714: ❌ Malformed line after cleaning: 'O'
# dev.txt:849: ❌ Malformed line after cleaning: 'O'
# dev.txt:1190: ❌ Malformed line after cleaning: 'O'
# dev.txt:1192: ❌ Malformed line after cleaning: 'O'
# dev.txt:2047: ❌ Malformed line after cleaning: 'O'
# dev.txt:2059: ❌ Malformed line after cleaning: 'O'
# dev.txt:4881: ❌ Malformed line after cleaning: 'O'
# dev.txt:5230: ❌ Malformed line after cleaning: 'O'
# dev.txt:5744: ❌ Malformed line after cleaning: 'O'
# dev.txt:5813: ❌ Malformed line after cleaning: 'O'
# dev.txt:7605: ❌ Malformed line after cleaning: 'O'
# dev.txt:7624: ❌ Malformed line after cleaning: 'O'
# dev.txt:7630: ❌ Malformed line after cleaning: 'O'
# dev.txt:7653: ❌ Malformed line after cleaning: 'O'
# dev.txt:7654: ❌ Malformed line after cleaning: 'O'
# dev.txt:7662: ❌ Malformed line after cleaning: 'O'
# dev.txt:7663: ❌ Malformed line after cleaning: 'O'
# dev.txt:7705: ❌ Malformed line after cleaning: 'O'
# dev.txt:8954: ❌ Malformed line after cleaning: 'O'
# dev.txt:8956: ❌ Malformed line after cleaning: 'O'
# dev.txt:10638: ❌ Malformed line after cleaning: 'O'
# dev.txt:10649: ❌ Malformed line after cleaning: 'O'
# dev.txt:10650: ❌ Malformed line after cleaning: 'O'
# dev.txt:10662: ❌ Malformed line after cleaning: 'O'
# dev.txt:10663: ❌ Malformed line after cleaning: 'O'
# dev.txt:10676: ❌ Malformed line after cleaning: 'O'
# dev.txt:10677: ❌ Malformed line after cleaning: 'O'
# dev.txt:10703: ❌ Malformed line after cleaning: 'O'
# dev.txt:10704: ❌ Malformed line after cleaning: 'O'
# dev.txt:10729: ❌ Malformed line after cleaning: 'O'
# dev.txt:10893: ❌ Malformed line after cleaning: 'O'
# dev.txt:11059: ❌ Malformed line after cleaning: 'O'
# dev.txt:11778: ❌ Malformed line after cleaning: 'O'
# dev.txt:11783: ❌ Malformed line after cleaning: 'O'
# dev.txt:11842: ❌ Malformed line after cleaning: 'O'
# dev.txt:12121: ❌ Malformed line after cleaning: 'O'
# dev.txt:12156: ❌ Malformed line after cleaning: 'O'
# dev.txt:12237: ❌ Malformed line after cleaning: 'O'
# dev.txt:12296: ❌ Malformed line after cleaning: 'O'
# dev.txt:12351: ❌ Malformed line after cleaning: 'O'
# dev.txt:12417: ❌ Malformed line after cleaning: 'O'
# dev.txt:12427: ❌ Malformed line after cleaning: 'O'
# dev.txt:12442: ❌ Malformed line after cleaning: 'O'
# dev.txt:12455: ❌ Malformed line after cleaning: 'O'
# dev.txt:12712: ❌ Malformed line after cleaning: 'O'
# dev.txt:12753: ❌ Malformed line after cleaning: 'O'
# dev.txt:14011: ❌ Malformed line after cleaning: 'O'
# dev.txt:14114: ❌ Malformed line after cleaning: 'O'
# dev.txt:14294: ❌ Malformed line after cleaning: 'O'
# dev.txt:14323: ❌ Malformed line after cleaning: 'O'
# dev.txt:15084: ❌ Malformed line after cleaning: 'O'
# dev.txt:15085: ❌ Malformed line after cleaning: 'O'
# dev.txt:15091: ❌ Malformed line after cleaning: 'O'
# dev.txt:17347: ❌ Malformed line after cleaning: 'O'
# dev.txt:18098: ❌ Malformed line after cleaning: 'O'
# dev.txt:18100: ❌ Malformed line after cleaning: 'O'
# dev.txt:19855: ❌ Malformed line after cleaning: 'O'
# dev.txt:19860: ❌ Malformed line after cleaning: 'O'
# dev.txt:19902: ❌ Malformed line after cleaning: 'O'
#
# 📂 Validating file: test.txt
# ------------------------------------------------------------
# test.txt:1449: ❌ Malformed line after cleaning: 'O'
# test.txt:1457: ❌ Malformed line after cleaning: 'O'
# test.txt:2365: ❌ Malformed line after cleaning: 'O'
# test.txt:2369: ❌ Malformed line after cleaning: 'O'
# test.txt:2520: ❌ Malformed line after cleaning: 'O'
# test.txt:2528: ❌ Malformed line after cleaning: 'O'
# test.txt:2698: ❌ Malformed line after cleaning: 'O'
# test.txt:2702: ❌ Malformed line after cleaning: 'O'
# test.txt:2703: ❌ Malformed line after cleaning: 'O'
# test.txt:2720: ❌ Malformed line after cleaning: 'O'
# test.txt:2822: ❌ Malformed line after cleaning: 'O'
# test.txt:2827: ❌ Malformed line after cleaning: 'O'
# test.txt:2847: ❌ Malformed line after cleaning: 'O'
# test.txt:2856: ❌ Malformed line after cleaning: 'O'
# test.txt:2877: ❌ Malformed line after cleaning: 'O'
# test.txt:3122: ❌ Malformed line after cleaning: 'O'
# test.txt:3126: ❌ Malformed line after cleaning: 'O'
# test.txt:3171: ❌ Malformed line after cleaning: 'O'
# test.txt:3180: ❌ Malformed line after cleaning: 'O'
# test.txt:3225: ❌ Malformed line after cleaning: 'O'
# test.txt:3229: ❌ Malformed line after cleaning: 'O'
# test.txt:3260: ❌ Malformed line after cleaning: 'O'
# test.txt:3267: ❌ Malformed line after cleaning: 'O'
# test.txt:3303: ❌ Malformed line after cleaning: 'O'
# test.txt:3307: ❌ Malformed line after cleaning: 'O'
# test.txt:3329: ❌ Malformed line after cleaning: 'O'
# test.txt:3335: ❌ Malformed line after cleaning: 'O'
# test.txt:3382: ❌ Malformed line after cleaning: 'O'
# test.txt:3386: ❌ Malformed line after cleaning: 'O'
# test.txt:3387: ❌ Malformed line after cleaning: 'O'
# test.txt:3396: ❌ Malformed line after cleaning: 'O'
# test.txt:3469: ❌ Malformed line after cleaning: 'O'
# test.txt:3479: ❌ Malformed line after cleaning: 'O'
# test.txt:3577: ❌ Malformed line after cleaning: 'O'
# test.txt:3655: ❌ Malformed line after cleaning: 'O'
# test.txt:3660: ❌ Malformed line after cleaning: 'O'
# test.txt:3768: ❌ Malformed line after cleaning: 'O'
# test.txt:3777: ❌ Malformed line after cleaning: 'O'
# test.txt:3939: ❌ Malformed line after cleaning: 'O'
# test.txt:3951: ❌ Malformed line after cleaning: 'O'
# test.txt:4017: ❌ Malformed line after cleaning: 'O'
# test.txt:4021: ❌ Malformed line after cleaning: 'O'
# test.txt:4142: ❌ Malformed line after cleaning: 'O'
# test.txt:4153: ❌ Malformed line after cleaning: 'O'
# test.txt:4174: ❌ Malformed line after cleaning: 'O'
# test.txt:4182: ❌ Malformed line after cleaning: 'O'
# test.txt:4341: ❌ Malformed line after cleaning: 'O'
# test.txt:4449: ❌ Malformed line after cleaning: 'O'
# test.txt:4453: ❌ Malformed line after cleaning: 'O'
# test.txt:4801: ❌ Malformed line after cleaning: 'O'
# test.txt:4815: ❌ Malformed line after cleaning: 'O'
# test.txt:5365: ❌ Malformed line after cleaning: 'O'
# test.txt:5429: ❌ Malformed line after cleaning: 'O'
# test.txt:5529: ❌ Malformed line after cleaning: 'O'
# test.txt:5564: ❌ Malformed line after cleaning: 'O'
# test.txt:5571: ❌ Malformed line after cleaning: 'O'
# test.txt:5597: ❌ Malformed line after cleaning: 'O'
# test.txt:5651: ❌ Malformed line after cleaning: 'O'
# test.txt:5657: ❌ Malformed line after cleaning: 'O'
# test.txt:5791: ❌ Malformed line after cleaning: 'O'
# test.txt:5796: ❌ Malformed line after cleaning: 'O'
# test.txt:6326: ❌ Malformed line after cleaning: 'O'
# test.txt:6330: ❌ Malformed line after cleaning: 'O'
# test.txt:6331: ❌ Malformed line after cleaning: 'O'
# test.txt:6340: ❌ Malformed line after cleaning: 'O'
# test.txt:6561: ❌ Malformed line after cleaning: 'O'
# test.txt:6806: ❌ Malformed line after cleaning: 'O'
# test.txt:6810: ❌ Malformed line after cleaning: 'O'
# test.txt:6811: ❌ Malformed line after cleaning: 'O'
# test.txt:6818: ❌ Malformed line after cleaning: 'O'
# test.txt:7395: ❌ Malformed line after cleaning: 'O'
# test.txt:7403: ❌ Malformed line after cleaning: 'O'
# test.txt:7460: ❌ Malformed line after cleaning: 'O'
# test.txt:7466: ❌ Malformed line after cleaning: 'O'
# test.txt:7489: ❌ Malformed line after cleaning: 'O'
# test.txt:7494: ❌ Malformed line after cleaning: 'O'
# test.txt:7572: ❌ Malformed line after cleaning: 'O'
# test.txt:7576: ❌ Malformed line after cleaning: 'O'
# test.txt:7577: ❌ Malformed line after cleaning: 'O'
# test.txt:7603: ❌ Malformed line after cleaning: 'O'
# test.txt:7973: ❌ Malformed line after cleaning: 'O'
# test.txt:7978: ❌ Malformed line after cleaning: 'O'
# test.txt:8058: ❌ Malformed line after cleaning: 'O'
# test.txt:8063: ❌ Malformed line after cleaning: 'O'
# test.txt:8100: ❌ Malformed line after cleaning: 'O'
# test.txt:8104: ❌ Malformed line after cleaning: 'O'
# test.txt:8153: ❌ Malformed line after cleaning: 'O'
# test.txt:8166: ❌ Malformed line after cleaning: 'O'
# test.txt:8232: ❌ Malformed line after cleaning: 'O'
# test.txt:8236: ❌ Malformed line after cleaning: 'O'
# test.txt:8262: ❌ Malformed line after cleaning: 'O'
# test.txt:8282: ❌ Malformed line after cleaning: 'O'
# test.txt:8384: ❌ Malformed line after cleaning: 'O'
# test.txt:8390: ❌ Malformed line after cleaning: 'O'
# test.txt:8494: ❌ Malformed line after cleaning: 'O'
# test.txt:8499: ❌ Malformed line after cleaning: 'O'
# test.txt:9331: ❌ Malformed line after cleaning: 'O'
# test.txt:9336: ❌ Malformed line after cleaning: 'O'
# test.txt:9678: ❌ Malformed line after cleaning: 'O'
# test.txt:9680: ❌ Malformed line after cleaning: 'O'
# test.txt:9688: ❌ Malformed line after cleaning: 'O'
# test.txt:10030: ❌ Malformed line after cleaning: 'O'
# test.txt:10034: ❌ Malformed line after cleaning: 'O'
# test.txt:10035: ❌ Malformed line after cleaning: 'O'
# test.txt:10046: ❌ Malformed line after cleaning: 'O'
# test.txt:10201: ❌ Malformed line after cleaning: 'O'
# test.txt:10205: ❌ Malformed line after cleaning: 'O'
# test.txt:10409: ❌ Malformed line after cleaning: 'O'
# test.txt:10414: ❌ Malformed line after cleaning: 'O'
# test.txt:10424: ❌ Malformed line after cleaning: 'O'
# test.txt:10436: ❌ Malformed line after cleaning: 'O'
# test.txt:10585: ❌ Malformed line after cleaning: 'O'
# test.txt:10795: ❌ Malformed line after cleaning: 'O'
# test.txt:10800: ❌ Malformed line after cleaning: 'O'
# test.txt:10801: ❌ Malformed line after cleaning: 'O'
# test.txt:10989: ❌ Malformed line after cleaning: 'O'
# test.txt:10997: ❌ Malformed line after cleaning: 'O'
# test.txt:11226: ❌ Malformed line after cleaning: 'O'
# test.txt:11230: ❌ Malformed line after cleaning: 'O'
# test.txt:11231: ❌ Malformed line after cleaning: 'O'
# test.txt:11243: ❌ Malformed line after cleaning: 'O'
# test.txt:11821: ❌ Malformed line after cleaning: 'O'
# test.txt:11830: ❌ Malformed line after cleaning: 'O'
# test.txt:12074: ❌ Malformed line after cleaning: 'O'
# test.txt:12076: ❌ Malformed line after cleaning: 'O'
# test.txt:12080: ❌ Malformed line after cleaning: 'O'
# test.txt:12170: ❌ Malformed line after cleaning: 'O'
# test.txt:12223: ❌ Malformed line after cleaning: 'O'
# test.txt:12230: ❌ Malformed line after cleaning: 'O'
# test.txt:12382: ❌ Malformed line after cleaning: 'O'
# test.txt:12387: ❌ Malformed line after cleaning: 'O'
# test.txt:12415: ❌ Malformed line after cleaning: 'O'
# test.txt:12419: ❌ Malformed line after cleaning: 'O'
# test.txt:12603: ❌ Malformed line after cleaning: 'O'
# test.txt:12614: ❌ Malformed line after cleaning: 'O'
# test.txt:12650: ❌ Malformed line after cleaning: 'O'
# test.txt:12654: ❌ Malformed line after cleaning: 'O'
# test.txt:12839: ❌ Malformed line after cleaning: 'O'
# test.txt:12847: ❌ Malformed line after cleaning: 'O'
# test.txt:13171: ❌ Malformed line after cleaning: 'O'
# test.txt:13190: ❌ Malformed line after cleaning: 'O'
# test.txt:13227: ❌ Malformed line after cleaning: 'O'
# test.txt:13239: ❌ Malformed line after cleaning: 'O'
# test.txt:13583: ❌ Malformed line after cleaning: 'O'
# test.txt:13598: ❌ Malformed line after cleaning: 'O'
# test.txt:13727: ❌ Malformed line after cleaning: 'O'
# test.txt:13731: ❌ Malformed line after cleaning: 'O'
# test.txt:13789: ❌ Malformed line after cleaning: 'O'
# test.txt:13796: ❌ Malformed line after cleaning: 'O'
# test.txt:13903: ❌ Malformed line after cleaning: 'O'
# test.txt:13907: ❌ Malformed line after cleaning: 'O'
# test.txt:13908: ❌ Malformed line after cleaning: 'O'
# test.txt:13917: ❌ Malformed line after cleaning: 'O'
# test.txt:14905: ❌ Malformed line after cleaning: 'O'
# test.txt:14911: ❌ Malformed line after cleaning: 'O'
# test.txt:15125: ❌ Malformed line after cleaning: 'O'
# test.txt:15136: ❌ Malformed line after cleaning: 'O'
# test.txt:16914: ❌ Malformed line after cleaning: 'O'
# test.txt:16925: ❌ Malformed line after cleaning: 'O'
# test.txt:17404: ❌ Malformed line after cleaning: 'O'
# test.txt:17417: ❌ Malformed line after cleaning: 'O'
# test.txt:17614: ❌ Malformed line after cleaning: 'O'
# test.txt:17620: ❌ Malformed line after cleaning: 'O'
# test.txt:17950: ❌ Malformed line after cleaning: 'O'
# test.txt:17957: ❌ Malformed line after cleaning: 'O'
# test.txt:18015: ❌ Malformed line after cleaning: 'O'
# test.txt:18023: ❌ Malformed line after cleaning: 'O'
# test.txt:18493: ❌ Malformed line after cleaning: 'O'
# test.txt:18497: ❌ Malformed line after cleaning: 'O'
# test.txt:18568: ❌ Malformed line after cleaning: 'O'
# test.txt:18572: ❌ Malformed line after cleaning: 'O'
# test.txt:18637: ❌ Malformed line after cleaning: 'O'
# test.txt:18643: ❌ Malformed line after cleaning: 'O'
# test.txt:18791: ❌ Malformed line after cleaning: 'O'
# test.txt:18795: ❌ Malformed line after cleaning: 'O'
# test.txt:18796: ❌ Malformed line after cleaning: 'O'
# test.txt:18807: ❌ Malformed line after cleaning: 'O'
# test.txt:18808: ❌ Malformed line after cleaning: 'O'
# test.txt:18812: ❌ Malformed line after cleaning: 'O'
# test.txt:18897: ❌ Malformed line after cleaning: 'O'
# test.txt:18904: ❌ Malformed line after cleaning: 'O'
# test.txt:18987: ❌ Malformed line after cleaning: 'O'
# test.txt:19004: ❌ Malformed line after cleaning: 'O'
# test.txt:19555: ❌ Malformed line after cleaning: 'O'
# test.txt:19559: ❌ Malformed line after cleaning: 'O'
# test.txt:19560: ❌ Malformed line after cleaning: 'O'
# test.txt:19570: ❌ Malformed line after cleaning: 'O'
# test.txt:20020: ❌ Malformed line after cleaning: 'O'
# test.txt:20026: ❌ Malformed line after cleaning: 'O'
# test.txt:20277: ❌ Malformed line after cleaning: 'O'
# test.txt:20281: ❌ Malformed line after cleaning: 'O'
# test.txt:20282: ❌ Malformed line after cleaning: 'O'
# test.txt:20303: ❌ Malformed line after cleaning: 'O'
# test.txt:20542: ❌ Malformed line after cleaning: 'O'
# test.txt:20546: ❌ Malformed line after cleaning: 'O'
# test.txt:20726: ❌ Malformed line after cleaning: 'O'
# test.txt:20731: ❌ Malformed line after cleaning: 'O'
# test.txt:21158: ❌ Malformed line after cleaning: 'O'
# test.txt:21168: ❌ Malformed line after cleaning: 'O'
# test.txt:21285: ❌ Malformed line after cleaning: 'O'
# test.txt:21346: ❌ Malformed line after cleaning: 'O'
# test.txt:21376: ❌ Malformed line after cleaning: 'O'
# test.txt:21379: ❌ Malformed line after cleaning: 'O'
# test.txt:21825: ❌ Malformed line after cleaning: 'O'
# test.txt:21829: ❌ Malformed line after cleaning: 'O'
# test.txt:22025: ❌ Malformed line after cleaning: 'O'
# test.txt:22028: ❌ Malformed line after cleaning: 'O'
# test.txt:22029: ❌ Malformed line after cleaning: 'O'
# test.txt:22038: ❌ Malformed line after cleaning: 'O'
# test.txt:22101: ❌ Malformed line after cleaning: 'O'
